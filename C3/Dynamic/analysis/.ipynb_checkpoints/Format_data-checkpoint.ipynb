# %% [markdown]
# Open and reshape data

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from os import listdir
import pdb

# %%
# READ AND FORMAT DATA FILES

def read_files(where,files):    
    Data=[];
    for f in files:
        print(f)
        Pair={};
        i1=f.find('-');
        i2=f.find('_');
        i3=f[i1+1:].find('-')+i1+1;
        i4=f[i2+1:].find('_')+i2+1;
        Pair['Teachers_age']=int(f[0:i1]);
        Pair['Teachers_Id']=int(f[i1+1:i2]);
        Pair['Learners_age']=int(f[i2+1:i3]);    
        Pair['Learners_Id']=int(f[i3+1:i4]);             
        if Pair['Teachers_Id']>=400 or Pair['Learners_Id']>=400:
            Pair['Conscent']=False;
        else:
            Pair['Conscent']=True;
            
        df = pd.read_csv(where+f, delimiter=',');
        columns=df.columns.tolist();        
        tuples = [tuple(x) for x in df.values];
        Pair['Total_time']=int(tuples[-1][columns.index('time_elapsed')])/60000; # minutes
        Pair['Trials']=[];
        n_trial=0;
        for row in tuples:
            if row[1]=='teacher' or row[1]=='learner':
                n_trial+=1;
                if n_trial>2: # first two trials are training                    
                    circles=row[columns.index('Circles')];
                    crosses=row[columns.index('Crosses')];
                    circles_list=[];
                    crosses_list=[];
                    if not(pd.isnull(circles)):           
                        circles=circles.split(",");            
                        for element in circles:                
                            if element[0]=='[':
                                element=element[1:];
                            if element[-1]==']':
                                element=element[0:-1];
                            circles_list.append(float(element));
                        circles_list = list(zip(*[iter(circles_list)] * 2));
                    if not(pd.isnull(crosses)):    
                        crosses=crosses.split(",");            
                        for element in crosses:
                            if element[0]=='[':
                                element=element[1:];
                            if element[-1]==']':
                                element=element[0:-1];
                            crosses_list.append(float(element));
                        crosses_list = list(zip(*[iter(crosses_list)] * 2))                                
                    teachers_box=row[columns.index('Teachers_Box')];
                    teachers_box=teachers_box[1:-1];
                    teachers_box=teachers_box.split(",");   
                    aux=[];
                    for element in teachers_box:
                        element=int(element);
                        aux.append(element);
                    teachers_box=aux;
                    learners_guess=row[columns.index('Learners_Guess')];
                    learners_guess=learners_guess.split(",");
                    learners_guess_list=[];
                    for element in learners_guess:
                        if element[0]=='[':
                            element=element[1:];
                        if element[-1]==']':
                            element=element[0:-1];
                        learners_guess_list.append(float(element));
                    learners_guess_list = list(zip(*[iter(learners_guess_list)] * 4))  
                    won=row[columns.index('won')];
                    Pair['Trials'].append({'Teachers_box':teachers_box,'Circles':circles_list,'Crosses':crosses_list,'Learners_guess':learners_guess_list,'won':won});
        Data.append(Pair);
    return Data;

# %%
# ADD MISSING FILES

where='/home/ahaimovici/Documents/Teaching/Rectangle_Game/C3/Data/Dynamic/without_time_info/teachers/';
files=[];
for file in listdir(where):
    if file.endswith(".csv"):
        files.append(file);

Data=read_files(where,files);


where='/home/ahaimovici/Documents/Teaching/Rectangle_Game/C3/Data/Dynamic/without_time_info/learners/';
files=[];
for file in listdir(where):
    if file.endswith(".csv"):
        files.append(file);
Data_L=read_files(where,files);

New_data=[];
for P in Data_L:
    new_pair=True;
    for Q in Data:
        if P['Teachers_Id']==Q['Teachers_Id'] and P['Learners_Id']==Q['Learners_Id']:
            new_pair=False;
    if new_pair:
        New_data.append(P);
for P in New_data:
    Data.append(P);
# Out:
# 40-10_35-11_teacher_dynamic.csv
# 10-233_10-232_teacher_dynamic.csv
# 10-211_12-204_teacher_dynamic.csv
# 16-224_18-16_teacher_dynamic.csv
# 10-232_10-233_teacher_dynamic.csv
# 8-215_7-216_teacher_dynamic.csv
# 42-8_56-07_teacher_dynamic.csv
# 7-215_7-252_teacher_dynamic.csv
# 10-242_10-234_teacher_dynamic.csv
# 8-403_8-223_teacher_dynamic.csv
# 38-5_50-3_teacher_dynamic.csv
# 10-210_9-213_teacher_dynamic.csv
# 9-201_9-01_teacher_dynamic.csv
# 56-25_52-24_teacher_dynamic.csv
# 28-200_20-02_teacher_dynamic.csv
# 56-25_52-24_learner_dynamic.csv
# 10-242_10-234_learner_dynamic.csv
# 6-217_11-218_learner_dynamic.csv
# 38-5_50-3_learner_dynamic.csv
# 7-215_7-252_learner_dynamic.csv
# 28-200_20-02_learner_dynamic.csv
# 16-224_18-16_learner_dynamic.csv
# 10-211_12-204_learner_dynamic.csv
# 9-201_9-01_learner_dynamic.csv
# 10-210_9-213_learner_dynamic.csv
# 10-233_10-232_learner_dynamic.csv
# 8-215_7-216_learner_dynamic.csv
# 8-403_8-223_learner_dynamic.csv
# 40-10_35-11_learner_dynamic.csv
# 42-8_56-07_learner_dynamic.csv

# %%
Data
# Out:
# [{'Conscent': True,
#   'Learners_Id': 11,
#   'Learners_age': 35,
#   'Teachers_Id': 10,
#   'Teachers_age': 40,
#   'Total_time': 15.9152,
#   'Trials': [{'Circles': [(479.0, 175.0)],
#     'Crosses': [(457.0, 169.0), (599.0, 179.0), (533.0, 463.0)],
#     'Learners_guess': [(392.0, 495.0, 73.0, 184.0),
#      (468.0, 608.0, 170.0, 277.0),
#      (466.0, 589.0, 162.0, 247.0),
#      (471.0, 589.0, 166.0, 433.0)],
#     'Teachers_box': [466, 591, 157, 454],
#     'won': True},
#    {'Circles': [(626.0, 282.0), (631.0, 708.0)],
#     'Crosses': [(713.0, 285.0)],
#     'Learners_guess': [(610.0, 826.0, 275.0, 349.0),
#      (619.0, 646.0, 276.0, 718.0),
#      (620.0, 698.0, 274.0, 722.0)],
#     'Teachers_box': [618, 704, 269, 722],
#     'won': True},
#    {'Circles': [(682.0, 402.0)],
#     'Crosses': [(667.0, 401.0), (769.0, 401.0), (717.0, 510.0)],
#     'Learners_guess': [(153.0, 692.0, 395.0, 617.0),
#      (673.0, 814.0, 391.0, 505.0),
#      (674.0, 761.0, 395.0, 450.0),
#      (675.0, 760.0, 399.0, 496.0)],
#     'Teachers_box': [675, 761, 390, 502],
#     'won': True},
#    {'Circles': [(497.0, 658.0)],
#     'Crosses': [(486.0, 661.0), (506.0, 643.0), (585.0, 660.0)],
#     'Learners_guess': [(426.0, 509.0, 557.0, 671.0),
#      (493.0, 605.0, 576.0, 668.0),
#      (493.0, 501.0, 525.0, 665.0),
#      (491.0, 576.0, 653.0, 709.0)],
#     'Teachers_box': [491, 578, 649, 735],
#     'won': True},
#    {'Circles': [(238.0, 114.0), (731.0, 116.0)],
#     'Crosses': [(735.0, 566.0)],
#     'Learners_guess': [(228.0, 293.0, 32.0, 125.0),
#      (228.0, 743.0, 108.0, 124.0),
#      (228.0, 744.0, 111.0, 551.0)],
#     'Teachers_box': [230, 740, 104, 554],
#     'won': True},
#    {'Circles': [(661.0, 279.0)],
#     'Crosses': [(746.0, 279.0), (733.0, 462.0)],
#     'Learners_guess': [(651.0, 843.0, 269.0, 411.0),
#      (655.0, 738.0, 119.0, 291.0),
#      (652.0, 737.0, 271.0, 450.0)],
#     'Teachers_box': [652, 738, 268, 451],
#     'won': True},
#    {'Circles': [(310.0, 369.0)],
#     'Crosses': [(396.0, 367.0), (382.0, 554.0)],
#     'Learners_guess': [(301.0, 518.0, 361.0, 432.0),
#      (295.0, 389.0, 361.0, 460.0),
#      (302.0, 389.0, 364.0, 548.0)],
#     'Teachers_box': [301, 387, 358, 544],
#     'won': True},
#    {'Circles': [(482.0, 335.0)],
#     'Crosses': [(771.0, 335.0), (759.0, 778.0)],
#     'Learners_guess': [(473.0, 585.0, 327.0, 446.0),
#      (471.0, 762.0, 325.0, 438.0),
#      (475.0, 759.0, 327.0, 771.0)],
#     'Teachers_box': [471, 763, 323, 768],
#     'won': True},
#    {'Circles': [(266.0, 213.0), (724.0, 215.0)],
#     'Crosses': [(239.0, 210.0), (725.0, 705.0)],
#     'Learners_guess': [(129.0, 276.0, 101.0, 221.0),
#      (246.0, 275.0, 132.0, 220.0),
#      (251.0, 733.0, 204.0, 244.0),
#      (256.0, 737.0, 206.0, 696.0)],
#     'Teachers_box': [253, 734, 199, 691],
#     'won': True},
#    {'Circles': [(222.0, 535.0)],
#     'Crosses': [(308.0, 537.0)],
#     'Learners_guess': [(212.0, 431.0, 529.0, 670.0),
#      (212.0, 302.0, 529.0, 655.0)],
#     'Teachers_box': [214, 300, 525, 611],
#     'won': True},
#    {'Circles': [(619.0, 348.0)],
#     'Crosses': [(602.0, 350.0), (705.0, 349.0), (692.0, 472.0)],
#     'Learners_guess': [(414.0, 629.0, 343.0, 538.0),
#      (610.0, 773.0, 342.0, 517.0),
#      (610.0, 700.0, 344.0, 609.0),
#      (615.0, 700.0, 339.0, 461.0)],
#     'Teachers_box': [611, 697, 338, 464],
#     'won': True},
#    {'Circles': [(648.0, 338.0), (769.0, 410.0)],
#     'Crosses': [(630.0, 340.0), (651.0, 322.0)],
#     'Learners_guess': [(556.0, 656.0, 69.0, 348.0),
#      (639.0, 814.0, 152.0, 349.0),
#      (641.0, 812.0, 335.0, 526.0),
#      (641.0, 778.0, 331.0, 421.0)],
#     'Teachers_box': [641, 776, 330, 416],
#     'won': True},
#    {'Circles': [(213.0, 467.0)],
#     'Crosses': [(537.0, 471.0), (521.0, 643.0)],
#     'Learners_guess': [(205.0, 439.0, 291.0, 476.0),
#      (206.0, 527.0, 293.0, 481.0),
#      (203.0, 529.0, 461.0, 634.0)],
#     'Teachers_box': [201, 529, 456, 631],
#     'won': True},
#    {'Circles': [(299.0, 118.0)],
#     'Crosses': [(283.0, 119.0), (382.0, 117.0), (370.0, 404.0)],
#     'Learners_guess': [(89.0, 309.0, 29.0, 130.0),
#      (291.0, 461.0, 21.0, 129.0),
#      (291.0, 372.0, 109.0, 307.0),
#      (287.0, 372.0, 109.0, 393.0)],
#     'Teachers_box': [290, 376, 106, 391],
#     'won': True},
#    {'Circles': [(167.0, 409.0)],
#     'Crosses': [(619.0, 408.0), (601.0, 495.0)],
#     'Learners_guess': [(161.0, 343.0, 403.0, 550.0),
#      (158.0, 610.0, 396.0, 554.0),
#      (153.0, 611.0, 400.0, 486.0)],
#     'Teachers_box': [158, 611, 399, 485],
#     'won': True},
#    {'Circles': [(569.0, 431.0)],
#     'Crosses': [(554.0, 432.0), (659.0, 429.0)],
#     'Learners_guess': [(404.0, 577.0, 314.0, 442.0),
#      (563.0, 791.0, 427.0, 523.0),
#      (560.0, 652.0, 426.0, 508.0)],
#     'Teachers_box': [561, 653, 420, 512],
#     'won': True},
#    {'Circles': [(117.0, 355.0)],
#     'Crosses': [(663.0, 354.0), (645.0, 688.0)],
#     'Learners_guess': [(109.0, 264.0, 350.0, 466.0),
#      (107.0, 648.0, 348.0, 474.0),
#      (111.0, 651.0, 343.0, 676.0)],
#     'Teachers_box': [107, 655, 340, 678],
#     'won': True},
#    {'Circles': [(358.0, 554.0)],
#     'Crosses': [(337.0, 557.0), (772.0, 555.0)],
#     'Learners_guess': [(52.0, 375.0, 545.0, 758.0),
#      (349.0, 679.0, 550.0, 773.0),
#      (348.0, 765.0, 546.0, 750.0)],
#     'Teachers_box': [347, 765, 544, 725],
#     'won': True},
#    {'Circles': [(289.0, 679.0)],
#     'Crosses': [(388.0, 473.0), (292.0, 662.0), (668.0, 677.0)],
#     'Learners_guess': [(408.0, 805.0, 464.0, 665.0),
#      (276.0, 392.0, 489.0, 689.0),
#      (281.0, 515.0, 672.0, 792.0),
#      (282.0, 654.0, 673.0, 790.0)],
#     'Teachers_box': [281, 662, 670, 756],
#     'won': True},
#    {'Circles': [(681.0, 373.0)],
#     'Crosses': [(767.0, 370.0), (726.0, 522.0)],
#     'Learners_guess': [(662.0, 807.0, 362.0, 644.0),
#      (672.0, 758.0, 363.0, 466.0),
#      (677.0, 757.0, 363.0, 514.0)],
#     'Teachers_box': [675, 761, 364, 514],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 232,
#   'Learners_age': 10,
#   'Teachers_Id': 233,
#   'Teachers_age': 10,
#   'Total_time': 10.501433333333333,
#   'Trials': [{'Circles': [],
#     'Crosses': [(676.0, 507.0), (768.0, 650.0)],
#     'Learners_guess': [(620.0, 629.0, 478.0, 487.0),
#      (687.0, 786.0, 510.0, 641.0)],
#     'Teachers_box': [678, 764, 508, 647],
#     'won': True},
#    {'Circles': [(309.0, 667.0)],
#     'Crosses': [(578.0, 752.0)],
#     'Learners_guess': [(303.0, 415.0, 537.0, 674.0),
#      (298.0, 585.0, 660.0, 746.0)],
#     'Teachers_box': [305, 575, 662, 748],
#     'won': True},
#    {'Circles': [(336.0, 453.0), (143.0, 442.0)],
#     'Crosses': [(533.0, 527.0)],
#     'Learners_guess': [(174.0, 555.0, 262.0, 814.0),
#      (142.0, 351.0, 437.0, 519.0),
#      (136.0, 523.0, 431.0, 524.0)],
#     'Teachers_box': [139, 529, 438, 524],
#     'won': True},
#    {'Circles': [],
#     'Crosses': [(385.0, 661.0), (703.0, 750.0)],
#     'Learners_guess': [(284.0, 375.0, 536.0, 674.0),
#      (398.0, 708.0, 656.0, 740.0)],
#     'Teachers_box': [387, 700, 661, 747],
#     'won': True},
#    {'Circles': [(313.0, 595.0), (536.0, 676.0)],
#     'Crosses': [(542.0, 682.0)],
#     'Learners_guess': [(300.0, 409.0, 108.0, 578.0),
#      (318.0, 545.0, 585.0, 680.0),
#      (312.0, 541.0, 591.0, 680.0)],
#     'Teachers_box': [309, 539, 592, 678],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 204,
#   'Learners_age': 12,
#   'Teachers_Id': 211,
#   'Teachers_age': 10,
#   'Total_time': 12.83895,
#   'Trials': [{'Circles': [(512.0, 677.0), (758.0, 758.0), (509.0, 760.0)],
#     'Crosses': [],
#     'Learners_guess': [(495.0, 540.0, 672.0, 678.0),
#      (519.0, 751.0, 677.0, 759.0),
#      (497.0, 767.0, 675.0, 767.0)],
#     'Teachers_box': [506, 762, 672, 761],
#     'won': True},
#    {'Circles': [(682.0, 364.0), (604.0, 569.0)],
#     'Crosses': [],
#     'Learners_guess': [(646.0, 703.0, 357.0, 394.0),
#      (597.0, 694.0, 360.0, 575.0)],
#     'Teachers_box': [599, 685, 361, 571],
#     'won': True},
#    {'Circles': [(611.0, 353.0), (708.0, 614.0)],
#     'Crosses': [],
#     'Learners_guess': [(579.0, 613.0, 346.0, 376.0),
#      (607.0, 715.0, 347.0, 623.0)],
#     'Teachers_box': [605, 712, 348, 618],
#     'won': True},
#    {'Circles': [(619.0, 637.0), (699.0, 760.0)],
#     'Crosses': [],
#     'Learners_guess': [(447.0, 649.0, 583.0, 653.0),
#      (612.0, 708.0, 627.0, 771.0)],
#     'Teachers_box': [615, 701, 633, 765],
#     'won': True},
#    {'Circles': [(237.0, 454.0), (475.0, 531.0)],
#     'Crosses': [],
#     'Learners_guess': [(214.0, 340.0, 434.0, 528.0),
#      (227.0, 488.0, 451.0, 553.0)],
#     'Teachers_box': [232, 479, 449, 535],
#     'won': True},
#    {'Circles': [(755.0, 479.0), (607.0, 724.0)],
#     'Crosses': [],
#     'Learners_guess': [(695.0, 776.0, 468.0, 558.0),
#      (598.0, 770.0, 469.0, 738.0)],
#     'Teachers_box': [601, 759, 473, 729],
#     'won': True},
#    {'Circles': [(543.0, 204.0), (448.0, 275.0)],
#     'Crosses': [],
#     'Learners_guess': [(462.0, 572.0, 185.0, 340.0),
#      (432.0, 554.0, 196.0, 288.0)],
#     'Teachers_box': [441, 548, 197, 283],
#     'won': True},
#    {'Circles': [(541.0, 250.0), (138.0, 611.0)],
#     'Crosses': [],
#     'Learners_guess': [(7.0, 853.0, 19.0, 856.0),
#      (132.0, 553.0, 240.0, 623.0)],
#     'Teachers_box': [129, 545, 245, 617],
#     'won': True},
#    {'Circles': [(198.0, 518.0), (748.0, 592.0)],
#     'Crosses': [],
#     'Learners_guess': [(583.0, 588.0, 704.0, 708.0),
#      (192.0, 760.0, 510.0, 602.0)],
#     'Teachers_box': [192, 752, 512, 598],
#     'won': True},
#    {'Circles': [(165.0, 487.0), (250.0, 591.0)],
#     'Crosses': [],
#     'Learners_guess': [(306.0, 820.0, 598.0, 688.0),
#      (157.0, 257.0, 476.0, 599.0)],
#     'Teachers_box': [159, 254, 482, 595],
#     'won': True},
#    {'Circles': [(608.0, 355.0), (197.0, 430.0)],
#     'Crosses': [],
#     'Learners_guess': [(574.0, 626.0, 350.0, 434.0),
#      (190.0, 620.0, 349.0, 435.0)],
#     'Teachers_box': [190, 612, 349, 435],
#     'won': True},
#    {'Circles': [(686.0, 284.0), (764.0, 360.0)],
#     'Crosses': [],
#     'Learners_guess': [(421.0, 690.0, 284.0, 471.0),
#      (673.0, 774.0, 273.0, 367.0)],
#     'Teachers_box': [682, 768, 279, 365],
#     'won': True},
#    {'Circles': [(395.0, 566.0), (288.0, 638.0)],
#     'Crosses': [],
#     'Learners_guess': [(353.0, 661.0, 602.0, 840.0),
#      (279.0, 403.0, 555.0, 656.0)],
#     'Teachers_box': [281, 399, 559, 645],
#     'won': True},
#    {'Circles': [(511.0, 548.0), (730.0, 654.0)],
#     'Crosses': [],
#     'Learners_guess': [(622.0, 624.0, 491.0, 503.0),
#      (495.0, 749.0, 542.0, 670.0)],
#     'Teachers_box': [505, 734, 543, 657],
#     'won': True},
#    {'Circles': [(572.0, 197.0), (339.0, 273.0)],
#     'Crosses': [],
#     'Learners_guess': [(9.0, 439.0, 673.0, 705.0),
#      (330.0, 583.0, 187.0, 279.0)],
#     'Teachers_box': [331, 577, 191, 277],
#     'won': True},
#    {'Circles': [(369.0, 586.0), (633.0, 736.0)],
#     'Crosses': [],
#     'Learners_guess': [(322.0, 624.0, 569.0, 611.0),
#      (362.0, 646.0, 581.0, 748.0)],
#     'Teachers_box': [362, 639, 580, 741],
#     'won': True},
#    {'Circles': [(496.0, 314.0), (734.0, 384.0)],
#     'Crosses': [],
#     'Learners_guess': [(201.0, 383.0, 389.0, 700.0),
#      (488.0, 744.0, 306.0, 397.0)],
#     'Teachers_box': [489, 740, 308, 394],
#     'won': True},
#    {'Circles': [(403.0, 409.0), (727.0, 606.0)],
#     'Crosses': [],
#     'Learners_guess': [(372.0, 522.0, 402.0, 428.0),
#      (394.0, 742.0, 394.0, 617.0)],
#     'Teachers_box': [397, 732, 402, 612],
#     'won': True},
#    {'Circles': [(405.0, 651.0), (726.0, 727.0)],
#     'Crosses': [],
#     'Learners_guess': [(377.0, 513.0, 642.0, 673.0),
#      (399.0, 733.0, 645.0, 740.0)],
#     'Teachers_box': [399, 732, 646, 732],
#     'won': True},
#    {'Circles': [(248.0, 585.0), (664.0, 660.0)],
#     'Crosses': [],
#     'Learners_guess': [(198.0, 727.0, 542.0, 580.0),
#      (244.0, 680.0, 579.0, 670.0)],
#     'Teachers_box': [241, 669, 580, 666],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 16,
#   'Learners_age': 18,
#   'Teachers_Id': 224,
#   'Teachers_age': 16,
#   'Total_time': 10.737866666666667,
#   'Trials': [{'Circles': [(361.0, 675.0)],
#     'Crosses': [(411.0, 721.0), (311.0, 633.0), (409.0, 632.0)],
#     'Learners_guess': [(268.0, 513.0, 603.0, 730.0),
#      (270.0, 547.0, 603.0, 716.0),
#      (319.0, 551.0, 646.0, 707.0),
#      (306.0, 418.0, 642.0, 707.0)],
#     'Teachers_box': [315, 406, 633, 719],
#     'won': True},
#    {'Circles': [(317.0, 300.0), (708.0, 225.0)],
#     'Crosses': [],
#     'Learners_guess': [(301.0, 419.0, 274.0, 393.0),
#      (296.0, 738.0, 200.0, 311.0)],
#     'Teachers_box': [311, 715, 217, 303],
#     'won': True},
#    {'Circles': [(542.0, 313.0), (695.0, 609.0)],
#     'Crosses': [(533.0, 477.0)],
#     'Learners_guess': [(482.0, 615.0, 285.0, 396.0),
#      (511.0, 739.0, 305.0, 619.0),
#      (539.0, 706.0, 302.0, 621.0)],
#     'Teachers_box': [536, 699, 307, 614],
#     'won': True},
#    {'Circles': [(340.0, 462.0), (540.0, 761.0)],
#     'Crosses': [],
#     'Learners_guess': [(317.0, 461.0, 438.0, 544.0),
#      (326.0, 575.0, 440.0, 782.0)],
#     'Teachers_box': [333, 546, 455, 766],
#     'won': True},
#    {'Circles': [(395.0, 684.0), (712.0, 761.0)],
#     'Crosses': [],
#     'Learners_guess': [(338.0, 588.0, 615.0, 809.0),
#      (377.0, 721.0, 666.0, 785.0)],
#     'Teachers_box': [391, 716, 677, 763],
#     'won': True},
#    {'Circles': [(233.0, 658.0), (742.0, 772.0)],
#     'Crosses': [],
#     'Learners_guess': [(210.0, 345.0, 620.0, 691.0),
#      (218.0, 761.0, 639.0, 786.0)],
#     'Teachers_box': [228, 746, 653, 775],
#     'won': True},
#    {'Circles': [(357.0, 447.0), (477.0, 362.0)],
#     'Crosses': [(360.0, 351.0)],
#     'Learners_guess': [(350.0, 542.0, 422.0, 523.0),
#      (343.0, 499.0, 339.0, 477.0),
#      (349.0, 483.0, 355.0, 458.0)],
#     'Teachers_box': [353, 478, 357, 449],
#     'won': True},
#    {'Circles': [(672.0, 645.0), (770.0, 720.0)],
#     'Crosses': [],
#     'Learners_guess': [(485.0, 711.0, 555.0, 655.0),
#      (657.0, 777.0, 634.0, 725.0)],
#     'Teachers_box': [666, 775, 637, 723],
#     'won': True},
#    {'Circles': [(422.0, 555.0), (608.0, 758.0)],
#     'Crosses': [(864.0, 864.0),
#      (607.0, 763.0),
#      (619.0, 683.0),
#      (613.0, 684.0)],
#     'Learners_guess': [(291.0, 573.0, 151.0, 346.0),
#      (300.0, 556.0, 526.0, 563.0),
#      (319.0, 539.0, 509.0, 601.0),
#      (417.0, 623.0, 551.0, 764.0),
#      (418.0, 615.0, 551.0, 764.0),
#      (417.0, 611.0, 545.0, 761.0)],
#     'Teachers_box': [418, 610, 548, 763],
#     'won': True},
#    {'Circles': [(356.0, 126.0), (608.0, 211.0)],
#     'Crosses': [],
#     'Learners_guess': [(331.0, 467.0, 103.0, 224.0),
#      (348.0, 637.0, 118.0, 218.0)],
#     'Teachers_box': [352, 611, 122, 215],
#     'won': True},
#    {'Circles': [(147.0, 386.0), (474.0, 462.0)],
#     'Crosses': [],
#     'Learners_guess': [(140.0, 272.0, 377.0, 478.0),
#      (138.0, 486.0, 376.0, 473.0)],
#     'Teachers_box': [142, 478, 381, 467],
#     'won': True},
#    {'Circles': [(377.0, 311.0), (504.0, 462.0)],
#     'Crosses': [],
#     'Learners_guess': [(303.0, 598.0, 295.0, 405.0),
#      (368.0, 512.0, 296.0, 472.0)],
#     'Teachers_box': [373, 507, 308, 463],
#     'won': True},
#    {'Circles': [(355.0, 390.0), (709.0, 673.0)],
#     'Crosses': [],
#     'Learners_guess': [(348.0, 508.0, 381.0, 537.0),
#      (351.0, 715.0, 382.0, 691.0)],
#     'Teachers_box': [351, 711, 385, 679],
#     'won': True},
#    {'Circles': [(115.0, 144.0), (214.0, 367.0)],
#     'Crosses': [],
#     'Learners_guess': [(103.0, 286.0, 135.0, 278.0),
#      (109.0, 221.0, 128.0, 376.0)],
#     'Teachers_box': [111, 216, 139, 370],
#     'won': True},
#    {'Circles': [(115.0, 448.0)],
#     'Crosses': [],
#     'Learners_guess': [(109.0, 537.0, 441.0, 596.0)],
#     'Teachers_box': [112, 560, 445, 587],
#     'won': True},
#    {'Circles': [(89.0, 490.0), (353.0, 743.0)],
#     'Crosses': [],
#     'Learners_guess': [(72.0, 339.0, 475.0, 602.0),
#      (76.0, 363.0, 480.0, 752.0)],
#     'Teachers_box': [87, 355, 484, 745],
#     'won': True},
#    {'Circles': [(404.0, 585.0), (482.0, 339.0), (485.0, 585.0)],
#     'Crosses': [],
#     'Learners_guess': [(219.0, 412.0, 380.0, 604.0),
#      (386.0, 535.0, 333.0, 590.0),
#      (395.0, 512.0, 333.0, 588.0)],
#     'Teachers_box': [400, 486, 335, 587],
#     'won': True},
#    {'Circles': [(342.0, 332.0), (423.0, 466.0)],
#     'Crosses': [],
#     'Learners_guess': [(337.0, 608.0, 325.0, 451.0),
#      (334.0, 432.0, 315.0, 486.0)],
#     'Teachers_box': [339, 425, 330, 470],
#     'won': True},
#    {'Circles': [(649.0, 234.0), (729.0, 580.0)],
#     'Crosses': [(638.0, 371.0)],
#     'Learners_guess': [(463.0, 658.0, 224.0, 336.0),
#      (511.0, 740.0, 217.0, 616.0),
#      (645.0, 737.0, 223.0, 585.0)],
#     'Teachers_box': [645, 731, 230, 582],
#     'won': True},
#    {'Circles': [(332.0, 449.0)],
#     'Crosses': [],
#     'Learners_guess': [(328.0, 498.0, 437.0, 573.0)],
#     'Teachers_box': [328, 486, 446, 590],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 233,
#   'Learners_age': 10,
#   'Teachers_Id': 232,
#   'Teachers_age': 10,
#   'Total_time': 13.4184,
#   'Trials': [{'Circles': [(307.0, 191.0), (446.0, 265.0), (303.0, 267.0)],
#     'Crosses': [],
#     'Learners_guess': [(169.0, 685.0, 162.0, 443.0),
#      (171.0, 606.0, 163.0, 288.0),
#      (295.0, 459.0, 167.0, 275.0)],
#     'Teachers_box': [297, 451, 184, 270],
#     'won': True},
#    {'Circles': [(414.0, 283.0), (533.0, 535.0)],
#     'Crosses': [],
#     'Learners_guess': [(378.0, 450.0, 271.0, 313.0),
#      (408.0, 540.0, 277.0, 541.0)],
#     'Teachers_box': [402, 540, 277, 543],
#     'won': True},
#    {'Circles': [(556.0, 617.0), (625.0, 769.0)],
#     'Crosses': [(636.0, 614.0)],
#     'Learners_guess': [(454.0, 568.0, 580.0, 622.0),
#      (487.0, 628.0, 609.0, 619.0),
#      (548.0, 632.0, 613.0, 776.0)],
#     'Teachers_box': [544, 630, 608, 774],
#     'won': True},
#    {'Circles': [(279.0, 523.0), (613.0, 197.0)],
#     'Crosses': [(641.0, 493.0)],
#     'Learners_guess': [(333.0, 606.0, 333.0, 494.0),
#      (270.0, 323.0, 493.0, 554.0),
#      (271.0, 619.0, 190.0, 527.0)],
#     'Teachers_box': [268, 618, 188, 536],
#     'won': True},
#    {'Circles': [(636.0, 641.0),
#      (640.0, 719.0),
#      (591.0, 681.0),
#      (692.0, 686.0)],
#     'Crosses': [],
#     'Learners_guess': [(319.0, 646.0, 377.0, 648.0),
#      (628.0, 646.0, 635.0, 729.0),
#      (585.0, 647.0, 636.0, 724.0),
#      (584.0, 698.0, 635.0, 727.0)],
#     'Teachers_box': [574, 696, 638, 724],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 216,
#   'Learners_age': 7,
#   'Teachers_Id': 215,
#   'Teachers_age': 8,
#   'Total_time': 25.20225,
#   'Trials': [{'Circles': [(716.0, 605.0), (747.0, 572.0)],
#     'Crosses': [(760.0, 546.0), (674.0, 666.0)],
#     'Learners_guess': [(633.0, 853.0, 499.0, 680.0),
#      (648.0, 812.0, 577.0, 680.0),
#      (659.0, 822.0, 582.0, 644.0),
#      (678.0, 819.0, 560.0, 621.0)],
#     'Teachers_box': [653, 772, 565, 651],
#     'won': True},
#    {'Circles': [(692.0, 213.0), (584.0, 585.0), (249.0, 361.0)],
#     'Crosses': [(200.0, 260.0), (749.0, 254.0), (508.0, 624.0)],
#     'Learners_guess': [(601.0, 784.0, 139.0, 275.0),
#      (452.0, 743.0, 132.0, 621.0),
#      (128.0, 788.0, 156.0, 640.0),
#      (221.0, 852.0, 163.0, 643.0),
#      (214.0, 727.0, 168.0, 687.0),
#      (226.0, 728.0, 150.0, 609.0)],
#     'Teachers_box': [231, 729, 170, 602],
#     'won': True},
#    {'Circles': [(717.0, 748.0), (631.0, 348.0)],
#     'Crosses': [(763.0, 383.0)],
#     'Learners_guess': [(581.0, 846.0, 658.0, 847.0),
#      (530.0, 838.0, 300.0, 822.0),
#      (570.0, 742.0, 318.0, 778.0)],
#     'Teachers_box': [565, 741, 330, 763],
#     'won': True},
#    {'Circles': [(233.0, 498.0),
#      (193.0, 693.0),
#      (233.0, 389.0),
#      (193.0, 416.0),
#      (284.0, 380.0)],
#     'Crosses': [(300.0, 342.0), (314.0, 433.0), (160.0, 437.0)],
#     'Learners_guess': [(332.0, 642.0, 393.0, 659.0),
#      (355.0, 764.0, 366.0, 691.0),
#      (223.0, 523.0, 465.0, 632.0),
#      (104.0, 358.0, 473.0, 784.0),
#      (110.0, 266.0, 370.0, 746.0),
#      (47.0, 298.0, 375.0, 807.0),
#      (179.0, 267.0, 362.0, 766.0),
#      (183.0, 302.0, 364.0, 714.0)],
#     'Teachers_box': [174, 300, 361, 708],
#     'won': True},
#    {'Circles': [(560.0, 471.0),
#      (598.0, 473.0),
#      (513.0, 531.0),
#      (499.0, 473.0)],
#     'Crosses': [(602.0, 442.0), (475.0, 497.0), (505.0, 555.0)],
#     'Learners_guess': [(486.0, 655.0, 400.0, 575.0),
#      (499.0, 852.0, 427.0, 639.0),
#      (505.0, 709.0, 451.0, 646.0),
#      (530.0, 738.0, 463.0, 582.0),
#      (549.0, 655.0, 460.0, 599.0),
#      (514.0, 635.0, 465.0, 631.0),
#      (493.0, 628.0, 466.0, 540.0)],
#     'Teachers_box': [491, 606, 458, 544],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 7,
#   'Learners_age': 56,
#   'Teachers_Id': 8,
#   'Teachers_age': 42,
#   'Total_time': 10.653466666666667,
#   'Trials': [{'Circles': [(325.0, 137.0), (401.0, 275.0)],
#     'Crosses': [],
#     'Learners_guess': [(38.0, 337.0, 20.0, 146.0),
#      (319.0, 411.0, 131.0, 285.0)],
#     'Teachers_box': [319, 405, 128, 277],
#     'won': True},
#    {'Circles': [(592.0, 619.0), (669.0, 766.0)],
#     'Crosses': [],
#     'Learners_guess': [(233.0, 600.0, 321.0, 634.0),
#      (578.0, 680.0, 610.0, 775.0)],
#     'Teachers_box': [586, 672, 613, 769],
#     'won': True},
#    {'Circles': [(595.0, 326.0), (670.0, 401.0)],
#     'Crosses': [],
#     'Learners_guess': [(402.0, 608.0, 130.0, 339.0),
#      (582.0, 681.0, 315.0, 415.0)],
#     'Teachers_box': [588, 674, 320, 406],
#     'won': True},
#    {'Circles': [(518.0, 159.0), (593.0, 581.0)],
#     'Crosses': [],
#     'Learners_guess': [(504.0, 674.0, 144.0, 293.0),
#      (491.0, 607.0, 143.0, 592.0)],
#     'Teachers_box': [512, 598, 152, 586],
#     'won': True},
#    {'Circles': [(341.0, 166.0), (649.0, 531.0)],
#     'Crosses': [],
#     'Learners_guess': [(83.0, 350.0, 48.0, 178.0),
#      (324.0, 660.0, 158.0, 541.0)],
#     'Teachers_box': [334, 653, 161, 537],
#     'won': True},
#    {'Circles': [(519.0, 374.0), (595.0, 693.0)],
#     'Crosses': [],
#     'Learners_guess': [(363.0, 535.0, 58.0, 388.0),
#      (505.0, 610.0, 361.0, 707.0)],
#     'Teachers_box': [511, 597, 369, 696],
#     'won': True},
#    {'Circles': [(238.0, 543.0), (315.0, 758.0)],
#     'Crosses': [],
#     'Learners_guess': [(228.0, 661.0, 532.0, 808.0),
#      (221.0, 330.0, 528.0, 770.0)],
#     'Teachers_box': [232, 318, 538, 760],
#     'won': True},
#    {'Circles': [(127.0, 456.0), (271.0, 619.0)],
#     'Crosses': [],
#     'Learners_guess': [(116.0, 453.0, 52.0, 465.0),
#      (110.0, 289.0, 448.0, 636.0)],
#     'Teachers_box': [121, 273, 451, 621],
#     'won': True},
#    {'Circles': [(239.0, 508.0), (316.0, 584.0)],
#     'Crosses': [],
#     'Learners_guess': [(230.0, 445.0, 502.0, 719.0),
#      (223.0, 330.0, 496.0, 601.0)],
#     'Teachers_box': [232, 318, 502, 588],
#     'won': True},
#    {'Circles': [(567.0, 246.0), (644.0, 555.0)],
#     'Crosses': [],
#     'Learners_guess': [(553.0, 703.0, 238.0, 531.0),
#      (541.0, 653.0, 233.0, 571.0)],
#     'Teachers_box': [561, 647, 241, 558],
#     'won': True},
#    {'Circles': [(302.0, 367.0), (594.0, 769.0)],
#     'Crosses': [],
#     'Learners_guess': [(225.0, 321.0, 361.0, 614.0),
#      (291.0, 610.0, 349.0, 781.0)],
#     'Teachers_box': [296, 597, 361, 773],
#     'won': True},
#    {'Circles': [(384.0, 100.0), (463.0, 404.0)],
#     'Crosses': [],
#     'Learners_guess': [(373.0, 584.0, 90.0, 439.0),
#      (367.0, 473.0, 81.0, 419.0)],
#     'Teachers_box': [379, 465, 95, 406],
#     'won': True},
#    {'Circles': [(261.0, 237.0), (741.0, 368.0)],
#     'Crosses': [],
#     'Learners_guess': [(248.0, 379.0, 225.0, 491.0),
#      (241.0, 765.0, 218.0, 381.0)],
#     'Teachers_box': [255, 744, 231, 373],
#     'won': True},
#    {'Circles': [(251.0, 131.0), (413.0, 523.0)],
#     'Crosses': [],
#     'Learners_guess': [(234.0, 397.0, 118.0, 465.0),
#      (228.0, 426.0, 113.0, 537.0)],
#     'Teachers_box': [243, 415, 123, 529],
#     'won': True},
#    {'Circles': [(101.0, 543.0), (669.0, 617.0)],
#     'Crosses': [],
#     'Learners_guess': [(91.0, 550.0, 531.0, 674.0),
#      (77.0, 680.0, 522.0, 630.0)],
#     'Teachers_box': [92, 674, 537, 623],
#     'won': True},
#    {'Circles': [(675.0, 412.0), (750.0, 595.0)],
#     'Crosses': [],
#     'Learners_guess': [(662.0, 794.0, 402.0, 741.0),
#      (652.0, 768.0, 396.0, 620.0)],
#     'Teachers_box': [667, 753, 404, 599],
#     'won': True},
#    {'Circles': [(229.0, 250.0), (522.0, 713.0)],
#     'Crosses': [],
#     'Learners_guess': [(213.0, 651.0, 239.0, 451.0),
#      (215.0, 534.0, 226.0, 733.0)],
#     'Teachers_box': [222, 526, 241, 721],
#     'won': True},
#    {'Circles': [(147.0, 244.0), (589.0, 749.0)],
#     'Crosses': [],
#     'Learners_guess': [(135.0, 241.0, 231.0, 479.0),
#      (122.0, 603.0, 227.0, 759.0)],
#     'Teachers_box': [140, 596, 238, 754],
#     'won': True},
#    {'Circles': [(690.0, 670.0), (762.0, 742.0)],
#     'Crosses': [],
#     'Learners_guess': [(683.0, 772.0, 655.0, 849.0),
#      (666.0, 780.0, 652.0, 758.0)],
#     'Teachers_box': [682, 768, 660, 746],
#     'won': True},
#    {'Circles': [(188.0, 592.0), (712.0, 667.0)],
#     'Crosses': [],
#     'Learners_guess': [(176.0, 762.0, 580.0, 790.0),
#      (163.0, 722.0, 569.0, 679.0)],
#     'Teachers_box': [179, 718, 585, 672],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 252,
#   'Learners_age': 7,
#   'Teachers_Id': 215,
#   'Teachers_age': 7,
#   'Total_time': 31.738733333333332,
#   'Trials': [{'Circles': [(452.0, 467.0),
#      (640.0, 465.0),
#      (456.0, 744.0),
#      (585.0, 587.0),
#      (636.0, 743.0),
#      (639.0, 747.0)],
#     'Crosses': [(302.0, 476.0), (770.0, 400.0)],
#     'Learners_guess': [(518.0, 685.0, 663.0, 828.0),
#      (364.0, 498.0, 397.0, 818.0),
#      (376.0, 860.0, 287.0, 795.0),
#      (371.0, 851.0, 406.0, 750.0),
#      (400.0, 801.0, 415.0, 819.0),
#      (363.0, 797.0, 458.0, 782.0),
#      (425.0, 751.0, 459.0, 774.0),
#      (440.0, 744.0, 460.0, 806.0)],
#     'Teachers_box': [445, 645, 456, 752],
#     'won': False},
#    {'Circles': [(295.0, 580.0),
#      (335.0, 580.0),
#      (294.0, 610.0),
#      (316.0, 618.0),
#      (335.0, 608.0)],
#     'Crosses': [],
#     'Learners_guess': [(231.0, 589.0, 529.0, 692.0),
#      (197.0, 706.0, 249.0, 645.0),
#      (284.0, 650.0, 540.0, 665.0),
#      (174.0, 590.0, 568.0, 670.0),
#      (255.0, 360.0, 567.0, 637.0)],
#     'Teachers_box': [245, 378, 545, 631],
#     'won': True},
#    {'Circles': [(307.0, 395.0),
#      (323.0, 513.0),
#      (254.0, 378.0),
#      (249.0, 517.0),
#      (320.0, 376.0),
#      (252.0, 378.0),
#      (250.0, 441.0),
#      (263.0, 445.0)],
#     'Crosses': [],
#     'Learners_guess': [(242.0, 406.0, 351.0, 437.0),
#      (272.0, 383.0, 341.0, 580.0),
#      (128.0, 348.0, 354.0, 595.0),
#      (222.0, 453.0, 365.0, 663.0),
#      (155.0, 679.0, 333.0, 732.0),
#      (207.0, 831.0, 307.0, 769.0),
#      (94.0, 653.0, 362.0, 665.0),
#      (233.0, 348.0, 150.0, 620.0)],
#     'Teachers_box': [241, 327, 369, 518],
#     'won': False},
#    {'Circles': [(203.0, 167.0),
#      (128.0, 169.0),
#      (125.0, 408.0),
#      (202.0, 408.0),
#      (131.0, 261.0),
#      (147.0, 263.0),
#      (164.0, 263.0),
#      (179.0, 264.0)],
#     'Crosses': [],
#     'Learners_guess': [(139.0, 311.0, 162.0, 351.0),
#      (88.0, 252.0, 110.0, 298.0),
#      (54.0, 627.0, 146.0, 512.0),
#      (96.0, 230.0, 136.0, 476.0),
#      (79.0, 215.0, 103.0, 501.0),
#      (110.0, 221.0, 138.0, 592.0),
#      (112.0, 236.0, 132.0, 460.0),
#      (85.0, 242.0, 164.0, 485.0)],
#     'Teachers_box': [120, 206, 162, 411],
#     'won': False},
#    {'Circles': [(559.0, 676.0),
#      (635.0, 675.0),
#      (556.0, 747.0),
#      (635.0, 749.0),
#      (636.0, 752.0),
#      (559.0, 675.0),
#      (636.0, 675.0),
#      (598.0, 706.0)],
#     'Crosses': [],
#     'Learners_guess': [(406.0, 711.0, 629.0, 730.0),
#      (458.0, 745.0, 535.0, 756.0),
#      (484.0, 659.0, 433.0, 824.0),
#      (542.0, 662.0, 659.0, 822.0),
#      (306.0, 692.0, 669.0, 805.0),
#      (552.0, 670.0, 624.0, 790.0),
#      (463.0, 783.0, 600.0, 825.0),
#      (441.0, 811.0, 659.0, 785.0)],
#     'Teachers_box': [551, 637, 668, 754],
#     'won': False}]},
#  {'Conscent': True,
#   'Learners_Id': 234,
#   'Learners_age': 10,
#   'Teachers_Id': 242,
#   'Teachers_age': 10,
#   'Total_time': 27.290116666666666,
#   'Trials': [{'Circles': [(645.0, 567.0),
#      (608.0, 568.0),
#      (688.0, 581.0),
#      (648.0, 530.0)],
#     'Crosses': [(534.0, 554.0),
#      (680.0, 483.0),
#      (730.0, 653.0),
#      (654.0, 628.0)],
#     'Learners_guess': [(616.0, 696.0, 495.0, 651.0),
#      (417.0, 670.0, 509.0, 591.0),
#      (595.0, 678.0, 410.0, 714.0),
#      (563.0, 761.0, 407.0, 738.0),
#      (580.0, 767.0, 506.0, 686.0),
#      (558.0, 738.0, 519.0, 643.0),
#      (579.0, 719.0, 533.0, 617.0),
#      (560.0, 721.0, 508.0, 623.0)],
#     'Teachers_box': [600, 695, 525, 611],
#     'won': False},
#    {'Circles': [(569.0, 728.0),
#      (504.0, 727.0),
#      (667.0, 727.0),
#      (569.0, 687.0)],
#     'Crosses': [(435.0, 635.0), (686.0, 675.0), (699.0, 778.0)],
#     'Learners_guess': [(517.0, 645.0, 712.0, 784.0),
#      (396.0, 661.0, 673.0, 778.0),
#      (360.0, 715.0, 570.0, 835.0),
#      (471.0, 726.0, 634.0, 792.0),
#      (465.0, 740.0, 695.0, 796.0),
#      (436.0, 719.0, 694.0, 759.0),
#      (454.0, 675.0, 666.0, 744.0)],
#     'Teachers_box': [463, 675, 682, 768],
#     'won': True},
#    {'Circles': [(565.0, 279.0), (474.0, 280.0), (681.0, 312.0)],
#     'Crosses': [(380.0, 320.0), (557.0, 334.0)],
#     'Learners_guess': [(496.0, 616.0, 218.0, 582.0),
#      (368.0, 671.0, 224.0, 294.0),
#      (303.0, 724.0, 233.0, 356.0),
#      (401.0, 759.0, 267.0, 368.0),
#      (430.0, 706.0, 242.0, 326.0)],
#     'Teachers_box': [443, 691, 219, 327],
#     'won': True},
#    {'Circles': [(532.0, 372.0), (539.0, 251.0), (540.0, 146.0)],
#     'Crosses': [(531.0, 390.0), (437.0, 322.0)],
#     'Learners_guess': [(425.0, 440.0, 618.0, 685.0),
#      (387.0, 549.0, 277.0, 385.0),
#      (452.0, 666.0, 299.0, 379.0),
#      (502.0, 583.0, 148.0, 382.0),
#      (482.0, 591.0, 123.0, 385.0)],
#     'Teachers_box': [463, 591, 91, 384],
#     'won': True},
#    {'Circles': [(532.0, 427.0),
#      (520.0, 321.0),
#      (533.0, 553.0),
#      (493.0, 464.0),
#      (535.0, 582.0)],
#     'Crosses': [(528.0, 589.0), (485.0, 466.0), (580.0, 286.0)],
#     'Learners_guess': [(502.0, 618.0, 363.0, 648.0),
#      (496.0, 639.0, 150.0, 519.0),
#      (478.0, 630.0, 162.0, 672.0),
#      (495.0, 608.0, 216.0, 572.0),
#      (442.0, 600.0, 270.0, 577.0),
#      (488.0, 623.0, 276.0, 575.0),
#      (488.0, 624.0, 245.0, 588.0),
#      (490.0, 578.0, 305.0, 588.0)],
#     'Teachers_box': [489, 575, 288, 584],
#     'won': True},
#    {'Circles': [(452.0, 303.0),
#      (285.0, 159.0),
#      (628.0, 162.0),
#      (629.0, 452.0),
#      (286.0, 453.0)],
#     'Crosses': [],
#     'Learners_guess': [(409.0, 504.0, 215.0, 394.0),
#      (248.0, 568.0, 101.0, 421.0),
#      (184.0, 756.0, 72.0, 431.0),
#      (174.0, 752.0, 86.0, 521.0),
#      (274.0, 642.0, 142.0, 464.0)],
#     'Teachers_box': [280, 633, 156, 456],
#     'won': True},
#    {'Circles': [(219.0, 403.0), (500.0, 404.0), (500.0, 588.0)],
#     'Crosses': [],
#     'Learners_guess': [(217.0, 399.0, 274.0, 409.0),
#      (211.0, 539.0, 176.0, 430.0),
#      (202.0, 529.0, 394.0, 602.0)],
#     'Teachers_box': [215, 503, 400, 592],
#     'won': True},
#    {'Circles': [(307.0, 256.0)],
#     'Crosses': [],
#     'Learners_guess': [(292.0, 517.0, 242.0, 498.0)],
#     'Teachers_box': [301, 486, 253, 538],
#     'won': True},
#    {'Circles': [(181.0, 350.0),
#      (754.0, 352.0),
#      (753.0, 431.0),
#      (183.0, 425.0)],
#     'Crosses': [],
#     'Learners_guess': [(139.0, 375.0, 292.0, 602.0),
#      (53.0, 780.0, 171.0, 380.0),
#      (98.0, 786.0, 171.0, 514.0),
#      (181.0, 763.0, 340.0, 434.0)],
#     'Teachers_box': [179, 756, 346, 432],
#     'won': True},
#    {'Circles': [(227.0, 580.0), (560.0, 581.0), (559.0, 656.0)],
#     'Crosses': [],
#     'Learners_guess': [(223.0, 414.0, 375.0, 587.0),
#      (220.0, 565.0, 395.0, 586.0),
#      (217.0, 564.0, 573.0, 663.0)],
#     'Teachers_box': [222, 563, 575, 661],
#     'won': True},
#    {'Circles': [(420.0, 684.0), (560.0, 685.0), (418.0, 763.0)],
#     'Crosses': [],
#     'Learners_guess': [(279.0, 673.0, 669.0, 710.0),
#      (395.0, 581.0, 676.0, 817.0),
#      (412.0, 576.0, 683.0, 765.0)],
#     'Teachers_box': [414, 564, 678, 764],
#     'won': True},
#    {'Circles': [(379.0, 361.0), (458.0, 361.0), (380.0, 493.0)],
#     'Crosses': [],
#     'Learners_guess': [(371.0, 667.0, 229.0, 367.0),
#      (370.0, 463.0, 267.0, 364.0),
#      (369.0, 461.0, 357.0, 500.0)],
#     'Teachers_box': [375, 461, 358, 496],
#     'won': True},
#    {'Circles': [(570.0, 230.0), (650.0, 231.0), (572.0, 350.0)],
#     'Crosses': [],
#     'Learners_guess': [(398.0, 579.0, 226.0, 423.0),
#      (554.0, 658.0, 228.0, 409.0),
#      (565.0, 655.0, 225.0, 356.0)],
#     'Teachers_box': [566, 652, 226, 353],
#     'won': True},
#    {'Circles': [(264.0, 406.0), (511.0, 407.0), (265.0, 522.0)],
#     'Crosses': [],
#     'Learners_guess': [(257.0, 414.0, 208.0, 409.0),
#      (255.0, 517.0, 270.0, 411.0),
#      (261.0, 521.0, 398.0, 534.0)],
#     'Teachers_box': [260, 513, 402, 525],
#     'won': True},
#    {'Circles': [(573.0, 431.0),
#      (734.0, 431.0),
#      (734.0, 682.0),
#      (575.0, 681.0)],
#     'Crosses': [],
#     'Learners_guess': [(195.0, 582.0, 244.0, 436.0),
#      (568.0, 737.0, 176.0, 430.0),
#      (561.0, 739.0, 433.0, 686.0),
#      (572.0, 739.0, 425.0, 694.0)],
#     'Teachers_box': [569, 737, 427, 683],
#     'won': True},
#    {'Circles': [(143.0, 668.0), (223.0, 668.0), (144.0, 748.0)],
#     'Crosses': [],
#     'Learners_guess': [(132.0, 451.0, 617.0, 674.0),
#      (133.0, 233.0, 437.0, 673.0),
#      (137.0, 232.0, 667.0, 752.0)],
#     'Teachers_box': [139, 225, 664, 750],
#     'won': True},
#    {'Circles': [(403.0, 284.0), (768.0, 284.0), (768.0, 618.0)],
#     'Crosses': [],
#     'Learners_guess': [(393.0, 594.0, 280.0, 420.0),
#      (391.0, 775.0, 283.0, 500.0),
#      (393.0, 777.0, 272.0, 627.0)],
#     'Teachers_box': [400, 770, 281, 619],
#     'won': True},
#    {'Circles': [(528.0, 665.0), (732.0, 666.0), (528.0, 745.0)],
#     'Crosses': [],
#     'Learners_guess': [(575.0, 576.0, 494.0, 495.0),
#      (522.0, 738.0, 508.0, 673.0),
#      (523.0, 740.0, 658.0, 753.0)],
#     'Teachers_box': [524, 735, 662, 748],
#     'won': True},
#    {'Circles': [(631.0, 476.0), (765.0, 477.0), (764.0, 705.0)],
#     'Crosses': [],
#     'Learners_guess': [(223.0, 636.0, 118.0, 485.0),
#      (625.0, 772.0, 323.0, 482.0),
#      (625.0, 772.0, 474.0, 710.0)],
#     'Teachers_box': [627, 767, 472, 708],
#     'won': True},
#    {'Circles': [(108.0, 480.0), (307.0, 481.0), (109.0, 558.0)],
#     'Crosses': [],
#     'Learners_guess': [(108.0, 240.0, 471.0, 728.0),
#      (104.0, 314.0, 477.0, 726.0),
#      (103.0, 322.0, 472.0, 565.0)],
#     'Teachers_box': [104, 309, 476, 562],
#     'won': True}]},
#  {'Conscent': False,
#   'Learners_Id': 223,
#   'Learners_age': 8,
#   'Teachers_Id': 403,
#   'Teachers_age': 8,
#   'Total_time': 31.9108,
#   'Trials': [{'Circles': [],
#     'Crosses': [(637.0, 497.0),
#      (810.0, 500.0),
#      (793.0, 292.0),
#      (642.0, 298.0),
#      (803.0, 412.0),
#      (644.0, 404.0),
#      (728.0, 536.0),
#      (720.0, 263.0)],
#     'Learners_guess': [(413.0, 585.0, 412.0, 508.0),
#      (441.0, 539.0, 278.0, 369.0),
#      (700.0, 810.0, 95.0, 205.0),
#      (334.0, 458.0, 251.0, 338.0),
#      (671.0, 788.0, 652.0, 744.0),
#      (660.0, 796.0, 118.0, 190.0),
#      (688.0, 789.0, 558.0, 600.0),
#      (709.0, 759.0, 370.0, 486.0)],
#     'Teachers_box': [682, 768, 295, 505],
#     'won': False},
#    {'Circles': [(432.0, 602.0), (195.0, 611.0), (660.0, 600.0)],
#     'Crosses': [(684.0, 471.0),
#      (141.0, 469.0),
#      (156.0, 726.0),
#      (691.0, 718.0),
#      (408.0, 457.0)],
#     'Learners_guess': [(409.0, 497.0, 553.0, 618.0),
#      (530.0, 584.0, 530.0, 586.0),
#      (226.0, 294.0, 523.0, 606.0),
#      (408.0, 521.0, 622.0, 673.0),
#      (402.0, 506.0, 546.0, 632.0),
#      (260.0, 372.0, 568.0, 612.0),
#      (503.0, 616.0, 632.0, 668.0),
#      (360.0, 454.0, 618.0, 702.0)],
#     'Teachers_box': [157, 691, 500, 698],
#     'won': False},
#    {'Circles': [(579.0, 432.0), (594.0, 514.0)],
#     'Crosses': [(430.0, 590.0),
#      (758.0, 603.0),
#      (733.0, 294.0),
#      (422.0, 300.0),
#      (776.0, 431.0),
#      (396.0, 427.0)],
#     'Learners_guess': [(469.0, 523.0, 697.0, 799.0),
#      (470.0, 534.0, 368.0, 443.0),
#      (554.0, 619.0, 415.0, 457.0),
#      (410.0, 464.0, 340.0, 393.0),
#      (541.0, 621.0, 396.0, 475.0),
#      (627.0, 705.0, 392.0, 441.0),
#      (509.0, 567.0, 440.0, 497.0),
#      (503.0, 606.0, 412.0, 565.0)],
#     'Teachers_box': [432, 753, 329, 548],
#     'won': False},
#    {'Circles': [(520.0, 612.0)],
#     'Crosses': [(508.0, 401.0),
#      (518.0, 814.0),
#      (273.0, 595.0),
#      (784.0, 602.0),
#      (292.0, 432.0),
#      (282.0, 754.0),
#      (760.0, 433.0)],
#     'Learners_guess': [(498.0, 576.0, 218.0, 291.0),
#      (496.0, 564.0, 537.0, 615.0),
#      (390.0, 493.0, 564.0, 659.0),
#      (496.0, 607.0, 589.0, 654.0),
#      (494.0, 560.0, 573.0, 649.0),
#      (489.0, 559.0, 527.0, 650.0),
#      (482.0, 557.0, 556.0, 616.0),
#      (493.0, 613.0, 573.0, 684.0)],
#     'Teachers_box': [321, 743, 456, 767],
#     'won': False},
#    {'Circles': [(566.0, 267.0), (564.0, 206.0), (562.0, 333.0)],
#     'Crosses': [],
#     'Learners_guess': [(557.0, 662.0, 240.0, 364.0),
#      (539.0, 673.0, 172.0, 287.0),
#      (547.0, 687.0, 173.0, 376.0)],
#     'Teachers_box': [507, 628, 183, 348],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 3,
#   'Learners_age': 50,
#   'Teachers_Id': 5,
#   'Teachers_age': 38,
#   'Total_time': 17.820633333333333,
#   'Trials': [{'Circles': [(273.0, 471.0), (669.0, 469.0), (669.0, 605.0)],
#     'Crosses': [],
#     'Learners_guess': [(260.0, 533.0, 364.0, 481.0),
#      (264.0, 680.0, 288.0, 482.0),
#      (265.0, 682.0, 460.0, 619.0)],
#     'Teachers_box': [263, 676, 453, 612],
#     'won': True},
#    {'Circles': [(682.0, 579.0), (752.0, 651.0)],
#     'Crosses': [(677.0, 667.0)],
#     'Learners_guess': [(43.0, 652.0, 342.0, 831.0),
#      (672.0, 841.0, 479.0, 592.0),
#      (673.0, 766.0, 572.0, 658.0)],
#     'Teachers_box': [673, 759, 569, 655],
#     'won': True},
#    {'Circles': [(374.0, 544.0), (380.0, 436.0)],
#     'Crosses': [],
#     'Learners_guess': [(366.0, 509.0, 534.0, 641.0),
#      (366.0, 517.0, 425.0, 553.0)],
#     'Teachers_box': [366, 555, 425, 548],
#     'won': True},
#    {'Circles': [(391.0, 270.0), (278.0, 275.0), (275.0, 342.0)],
#     'Crosses': [(337.0, 363.0)],
#     'Learners_guess': [(384.0, 539.0, 263.0, 501.0),
#      (269.0, 405.0, 257.0, 492.0),
#      (260.0, 419.0, 22.0, 294.0),
#      (250.0, 404.0, 262.0, 352.0)],
#     'Teachers_box': [268, 398, 263, 349],
#     'won': True},
#    {'Circles': [(336.0, 586.0), (707.0, 299.0)],
#     'Crosses': [],
#     'Learners_guess': [(327.0, 462.0, 576.0, 671.0),
#      (327.0, 725.0, 286.0, 598.0)],
#     'Teachers_box': [325, 715, 288, 593],
#     'won': True},
#    {'Circles': [(363.0, 668.0)],
#     'Crosses': [],
#     'Learners_guess': [(355.0, 518.0, 661.0, 775.0)],
#     'Teachers_box': [355, 512, 659, 760],
#     'won': True},
#    {'Circles': [(735.0, 237.0), (231.0, 165.0)],
#     'Crosses': [],
#     'Learners_guess': [(601.0, 750.0, 224.0, 584.0),
#      (217.0, 752.0, 143.0, 262.0)],
#     'Teachers_box': [223, 743, 157, 243],
#     'won': True},
#    {'Circles': [(229.0, 355.0), (723.0, 423.0)],
#     'Crosses': [],
#     'Learners_guess': [(220.0, 423.0, 343.0, 432.0),
#      (214.0, 742.0, 340.0, 448.0)],
#     'Teachers_box': [219, 726, 344, 430],
#     'won': True},
#    {'Circles': [(483.0, 629.0), (185.0, 703.0)],
#     'Crosses': [],
#     'Learners_guess': [(475.0, 703.0, 621.0, 765.0),
#      (172.0, 495.0, 620.0, 725.0)],
#     'Teachers_box': [177, 491, 622, 708],
#     'won': True},
#    {'Circles': [(306.0, 260.0), (655.0, 327.0)],
#     'Crosses': [],
#     'Learners_guess': [(71.0, 318.0, 252.0, 358.0),
#      (289.0, 677.0, 245.0, 357.0)],
#     'Teachers_box': [297, 660, 248, 334],
#     'won': True},
#    {'Circles': [(258.0, 255.0), (475.0, 384.0)],
#     'Crosses': [],
#     'Learners_guess': [(247.0, 670.0, 245.0, 357.0),
#      (249.0, 485.0, 246.0, 397.0)],
#     'Teachers_box': [252, 477, 246, 392],
#     'won': True},
#    {'Circles': [(385.0, 511.0), (704.0, 148.0)],
#     'Crosses': [],
#     'Learners_guess': [(374.0, 680.0, 502.0, 637.0),
#      (376.0, 725.0, 132.0, 529.0)],
#     'Teachers_box': [376, 711, 138, 518],
#     'won': True},
#    {'Circles': [(296.0, 633.0), (143.0, 704.0)],
#     'Crosses': [],
#     'Learners_guess': [(287.0, 631.0, 258.0, 647.0),
#      (123.0, 317.0, 618.0, 731.0)],
#     'Teachers_box': [134, 302, 624, 710],
#     'won': True},
#    {'Circles': [(582.0, 584.0), (655.0, 258.0)],
#     'Crosses': [],
#     'Learners_guess': [(396.0, 599.0, 414.0, 597.0),
#      (567.0, 672.0, 233.0, 599.0)],
#     'Teachers_box': [573, 659, 252, 587],
#     'won': True},
#    {'Circles': [(659.0, 609.0), (770.0, 768.0)],
#     'Crosses': [],
#     'Learners_guess': [(649.0, 761.0, 250.0, 626.0),
#      (651.0, 778.0, 601.0, 784.0)],
#     'Teachers_box': [653, 774, 597, 776],
#     'won': True},
#    {'Circles': [(331.0, 267.0), (412.0, 491.0)],
#     'Crosses': [],
#     'Learners_guess': [(325.0, 526.0, 259.0, 427.0),
#      (321.0, 421.0, 257.0, 503.0)],
#     'Teachers_box': [324, 418, 259, 495],
#     'won': True},
#    {'Circles': [(262.0, 462.0), (754.0, 187.0)],
#     'Crosses': [],
#     'Learners_guess': [(251.0, 421.0, 196.0, 474.0),
#      (251.0, 774.0, 157.0, 474.0)],
#     'Teachers_box': [251, 763, 179, 471],
#     'won': True},
#    {'Circles': [(346.0, 701.0), (566.0, 771.0)],
#     'Crosses': [],
#     'Learners_guess': [(153.0, 365.0, 297.0, 720.0),
#      (331.0, 597.0, 688.0, 798.0)],
#     'Teachers_box': [340, 569, 691, 777],
#     'won': True},
#    {'Circles': [(380.0, 660.0), (302.0, 112.0)],
#     'Crosses': [],
#     'Learners_guess': [(366.0, 497.0, 522.0, 672.0),
#      (292.0, 402.0, 103.0, 679.0)],
#     'Teachers_box': [298, 384, 105, 666],
#     'won': True},
#    {'Circles': [(552.0, 106.0), (636.0, 673.0)],
#     'Crosses': [],
#     'Learners_guess': [(411.0, 566.0, 94.0, 557.0),
#      (540.0, 652.0, 95.0, 693.0)],
#     'Teachers_box': [546, 643, 95, 677],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 213,
#   'Learners_age': 9,
#   'Teachers_Id': 210,
#   'Teachers_age': 10,
#   'Total_time': 25.89815,
#   'Trials': [{'Circles': [(238.0, 550.0), (240.0, 163.0), (331.0, 360.0)],
#     'Crosses': [(239.0, 153.0),
#      (339.0, 360.0),
#      (237.0, 559.0),
#      (139.0, 363.0)],
#     'Learners_guess': [(276.0, 477.0, 331.0, 438.0),
#      (195.0, 407.0, 208.0, 321.0),
#      (149.0, 275.0, 250.0, 441.0),
#      (176.0, 294.0, 259.0, 460.0),
#      (180.0, 297.0, 351.0, 555.0),
#      (172.0, 302.0, 159.0, 555.0),
#      (173.0, 334.0, 159.0, 554.0)],
#     'Teachers_box': [143, 334, 158, 554],
#     'won': True},
#    {'Circles': [(311.0, 119.0), (557.0, 197.0)],
#     'Crosses': [(431.0, 210.0), (430.0, 113.0)],
#     'Learners_guess': [(252.0, 389.0, 78.0, 191.0),
#      (246.0, 632.0, 86.0, 273.0),
#      (256.0, 617.0, 48.0, 203.0),
#      (297.0, 560.0, 114.0, 202.0)],
#     'Teachers_box': [304, 560, 114, 200],
#     'won': True},
#    {'Circles': [(272.0, 468.0), (698.0, 453.0), (478.0, 221.0)],
#     'Crosses': [(476.0, 214.0),
#      (487.0, 691.0),
#      (704.0, 454.0),
#      (264.0, 466.0)],
#     'Learners_guess': [(398.0, 628.0, 304.0, 376.0),
#      (307.0, 700.0, 226.0, 616.0),
#      (212.0, 754.0, 264.0, 581.0),
#      (261.0, 654.0, 341.0, 623.0),
#      (269.0, 671.0, 308.0, 626.0),
#      (271.0, 702.0, 308.0, 618.0),
#      (271.0, 701.0, 217.0, 647.0)],
#     'Teachers_box': [267, 700, 216, 687],
#     'won': True},
#    {'Circles': [(667.0, 628.0), (745.0, 730.0)],
#     'Crosses': [(660.0, 618.0), (756.0, 730.0)],
#     'Learners_guess': [(603.0, 816.0, 582.0, 751.0),
#      (570.0, 827.0, 540.0, 748.0),
#      (651.0, 789.0, 626.0, 733.0),
#      (663.0, 751.0, 625.0, 737.0)],
#     'Teachers_box': [661, 747, 622, 732],
#     'won': True},
#    {'Circles': [(365.0, 730.0), (377.0, 388.0), (187.0, 528.0)],
#     'Crosses': [(379.0, 366.0), (569.0, 464.0), (180.0, 516.0)],
#     'Learners_guess': [(438.0, 638.0, 376.0, 539.0),
#      (385.0, 562.0, 363.0, 468.0),
#      (358.0, 522.0, 394.0, 737.0),
#      (215.0, 542.0, 426.0, 749.0),
#      (252.0, 498.0, 379.0, 735.0),
#      (184.0, 563.0, 385.0, 739.0)],
#     'Teachers_box': [182, 563, 372, 735],
#     'won': True},
#    {'Circles': [(439.0, 483.0), (538.0, 654.0)],
#     'Crosses': [],
#     'Learners_guess': [(204.0, 448.0, 242.0, 488.0),
#      (434.0, 542.0, 479.0, 659.0)],
#     'Teachers_box': [433, 540, 478, 655],
#     'won': True},
#    {'Circles': [(98.0, 388.0), (177.0, 619.0)],
#     'Crosses': [(185.0, 500.0)],
#     'Learners_guess': [(95.0, 441.0, 380.0, 534.0),
#      (94.0, 231.0, 385.0, 624.0),
#      (95.0, 181.0, 382.0, 624.0)],
#     'Teachers_box': [93, 179, 384, 621],
#     'won': True},
#    {'Circles': [(433.0, 534.0)],
#     'Crosses': [],
#     'Learners_guess': [(429.0, 560.0, 528.0, 703.0)],
#     'Teachers_box': [427, 551, 530, 710],
#     'won': True},
#    {'Circles': [(650.0, 197.0), (727.0, 395.0)],
#     'Crosses': [],
#     'Learners_guess': [(510.0, 654.0, 191.0, 350.0),
#      (646.0, 732.0, 192.0, 398.0)],
#     'Teachers_box': [644, 730, 191, 398],
#     'won': True},
#    {'Circles': [(687.0, 264.0), (766.0, 574.0)],
#     'Crosses': [],
#     'Learners_guess': [(519.0, 690.0, 261.0, 464.0),
#      (683.0, 770.0, 260.0, 577.0)],
#     'Teachers_box': [682, 768, 259, 576],
#     'won': True},
#    {'Circles': [(385.0, 257.0), (698.0, 370.0)],
#     'Crosses': [],
#     'Learners_guess': [(381.0, 589.0, 253.0, 485.0),
#      (381.0, 703.0, 254.0, 376.0)],
#     'Teachers_box': [379, 700, 252, 371],
#     'won': True},
#    {'Circles': [(123.0, 242.0), (568.0, 321.0)],
#     'Crosses': [(362.0, 328.0)],
#     'Learners_guess': [(120.0, 452.0, 237.0, 366.0),
#      (120.0, 574.0, 239.0, 370.0),
#      (121.0, 572.0, 237.0, 324.0)],
#     'Teachers_box': [118, 572, 237, 323],
#     'won': True},
#    {'Circles': [(99.0, 359.0), (489.0, 438.0)],
#     'Crosses': [],
#     'Learners_guess': [(95.0, 389.0, 354.0, 468.0),
#      (96.0, 494.0, 356.0, 444.0)],
#     'Teachers_box': [93, 493, 353, 439],
#     'won': True},
#    {'Circles': [(412.0, 420.0), (490.0, 726.0)],
#     'Crosses': [],
#     'Learners_guess': [(408.0, 516.0, 415.0, 606.0),
#      (407.0, 495.0, 414.0, 732.0)],
#     'Teachers_box': [406, 493, 415, 727],
#     'won': True},
#    {'Circles': [(476.0, 686.0), (773.0, 765.0)],
#     'Crosses': [],
#     'Learners_guess': [(369.0, 483.0, 381.0, 692.0),
#      (471.0, 777.0, 681.0, 770.0)],
#     'Teachers_box': [471, 775, 680, 766],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 1,
#   'Learners_age': 9,
#   'Teachers_Id': 201,
#   'Teachers_age': 9,
#   'Total_time': 23.94835,
#   'Trials': [{'Circles': [(455.0, 608.0), (583.0, 606.0), (576.0, 756.0)],
#     'Crosses': [],
#     'Learners_guess': [(353.0, 496.0, 502.0, 653.0),
#      (411.0, 638.0, 465.0, 670.0),
#      (427.0, 621.0, 575.0, 763.0)],
#     'Teachers_box': [430, 597, 588, 773],
#     'won': True},
#    {'Circles': [(618.0, 317.0)],
#     'Crosses': [(627.0, 230.0)],
#     'Learners_guess': [(340.0, 549.0, 487.0, 649.0),
#      (499.0, 674.0, 283.0, 468.0)],
#     'Teachers_box': [540, 707, 241, 401],
#     'won': True},
#    {'Circles': [(647.0, 560.0),
#      (315.0, 570.0),
#      (463.0, 647.0),
#      (484.0, 658.0)],
#     'Crosses': [(654.0, 539.0)],
#     'Learners_guess': [(548.0, 694.0, 512.0, 674.0),
#      (263.0, 694.0, 378.0, 677.0),
#      (296.0, 697.0, 494.0, 677.0),
#      (281.0, 663.0, 554.0, 712.0),
#      (299.0, 659.0, 553.0, 682.0)],
#     'Teachers_box': [289, 652, 557, 667],
#     'won': True},
#    {'Circles': [(649.0, 540.0),
#      (531.0, 550.0),
#      (767.0, 545.0),
#      (545.0, 589.0)],
#     'Crosses': [],
#     'Learners_guess': [(616.0, 721.0, 513.0, 622.0),
#      (513.0, 655.0, 529.0, 621.0),
#      (495.0, 817.0, 521.0, 657.0),
#      (515.0, 809.0, 523.0, 607.0)],
#     'Teachers_box': [524, 777, 494, 604],
#     'won': True},
#    {'Circles': [(661.0, 588.0),
#      (724.0, 658.0),
#      (658.0, 653.0),
#      (725.0, 580.0)],
#     'Crosses': [(637.0, 576.0), (737.0, 584.0)],
#     'Learners_guess': [(475.0, 685.0, 568.0, 656.0),
#      (605.0, 809.0, 577.0, 690.0),
#      (599.0, 808.0, 577.0, 680.0),
#      (570.0, 776.0, 555.0, 703.0),
#      (650.0, 795.0, 568.0, 690.0),
#      (645.0, 734.0, 565.0, 675.0)],
#     'Teachers_box': [645, 731, 571, 666],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 24,
#   'Learners_age': 52,
#   'Teachers_Id': 25,
#   'Teachers_age': 56,
#   'Total_time': 14.534816666666666,
#   'Trials': [{'Circles': [(253.0, 572.0), (431.0, 699.0)],
#     'Crosses': [],
#     'Learners_guess': [(239.0, 306.0, 568.0, 684.0),
#      (246.0, 445.0, 568.0, 733.0)],
#     'Teachers_box': [244, 437, 560, 708],
#     'won': True},
#    {'Circles': [(618.0, 444.0), (709.0, 641.0)],
#     'Crosses': [(725.0, 638.0)],
#     'Learners_guess': [(536.0, 644.0, 385.0, 446.0),
#      (589.0, 771.0, 443.0, 645.0),
#      (608.0, 717.0, 431.0, 655.0)],
#     'Teachers_box': [609, 715, 435, 648],
#     'won': True},
#    {'Circles': [(285.0, 649.0), (603.0, 717.0)],
#     'Crosses': [],
#     'Learners_guess': [(237.0, 356.0, 624.0, 702.0),
#      (278.0, 614.0, 641.0, 760.0)],
#     'Teachers_box': [275, 606, 641, 727],
#     'won': True},
#    {'Circles': [(682.0, 307.0)],
#     'Crosses': [],
#     'Learners_guess': [(657.0, 737.0, 288.0, 365.0)],
#     'Teachers_box': [673, 759, 298, 384],
#     'won': True},
#    {'Circles': [(255.0, 617.0), (733.0, 688.0)],
#     'Crosses': [],
#     'Learners_guess': [(235.0, 409.0, 594.0, 692.0),
#      (245.0, 743.0, 614.0, 720.0)],
#     'Teachers_box': [248, 738, 608, 694],
#     'won': True},
#    {'Circles': [(285.0, 210.0), (359.0, 418.0)],
#     'Crosses': [],
#     'Learners_guess': [(274.0, 405.0, 189.0, 270.0),
#      (279.0, 395.0, 194.0, 430.0)],
#     'Teachers_box': [281, 367, 201, 427],
#     'won': True},
#    {'Circles': [(198.0, 648.0), (347.0, 729.0)],
#     'Crosses': [(350.0, 747.0)],
#     'Learners_guess': [(171.0, 250.0, 613.0, 698.0),
#      (175.0, 420.0, 622.0, 774.0),
#      (180.0, 384.0, 631.0, 737.0)],
#     'Teachers_box': [189, 352, 641, 735],
#     'won': True},
#    {'Circles': [(168.0, 607.0), (644.0, 673.0)],
#     'Crosses': [],
#     'Learners_guess': [(139.0, 240.0, 596.0, 672.0),
#      (161.0, 651.0, 604.0, 691.0)],
#     'Teachers_box': [160, 653, 595, 681],
#     'won': True},
#    {'Circles': [(200.0, 420.0), (631.0, 708.0)],
#     'Crosses': [],
#     'Learners_guess': [(168.0, 227.0, 393.0, 454.0),
#      (182.0, 648.0, 404.0, 721.0)],
#     'Teachers_box': [191, 639, 413, 715],
#     'won': True},
#    {'Circles': [(546.0, 564.0), (653.0, 670.0)],
#     'Crosses': [],
#     'Learners_guess': [(534.0, 561.0, 557.0, 641.0),
#      (535.0, 664.0, 560.0, 697.0)],
#     'Teachers_box': [538, 657, 555, 676],
#     'won': True},
#    {'Circles': [(639.0, 445.0), (707.0, 708.0)],
#     'Crosses': [],
#     'Learners_guess': [(632.0, 771.0, 430.0, 520.0),
#      (632.0, 720.0, 439.0, 730.0)],
#     'Teachers_box': [629, 715, 436, 715],
#     'won': True},
#    {'Circles': [(126.0, 146.0), (648.0, 465.0)],
#     'Crosses': [],
#     'Learners_guess': [(110.0, 204.0, 138.0, 241.0),
#      (122.0, 654.0, 139.0, 477.0)],
#     'Teachers_box': [116, 657, 137, 473],
#     'won': True},
#    {'Circles': [(337.0, 261.0), (431.0, 651.0)],
#     'Crosses': [(447.0, 648.0)],
#     'Learners_guess': [(306.0, 441.0, 226.0, 486.0),
#      (309.0, 464.0, 230.0, 678.0),
#      (308.0, 437.0, 234.0, 681.0)],
#     'Teachers_box': [328, 439, 252, 660],
#     'won': True},
#    {'Circles': [(515.0, 498.0), (715.0, 595.0)],
#     'Crosses': [],
#     'Learners_guess': [(497.0, 742.0, 481.0, 795.0),
#      (508.0, 736.0, 487.0, 630.0)],
#     'Teachers_box': [502, 723, 487, 606],
#     'won': True},
#    {'Circles': [(354.0, 333.0), (562.0, 725.0)],
#     'Crosses': [],
#     'Learners_guess': [(335.0, 487.0, 300.0, 528.0),
#      (334.0, 574.0, 304.0, 745.0)],
#     'Teachers_box': [347, 569, 322, 735],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 2,
#   'Learners_age': 20,
#   'Teachers_Id': 200,
#   'Teachers_age': 28,
#   'Total_time': 16.460233333333335,
#   'Trials': [{'Circles': [(342.0, 697.0), (751.0, 700.0)],
#     'Crosses': [(304.0, 624.0),
#      (580.0, 498.0),
#      (483.0, 652.0),
#      (512.0, 773.0)],
#     'Learners_guess': [(330.0, 633.0, 542.0, 720.0),
#      (319.0, 782.0, 522.0, 721.0),
#      (333.0, 777.0, 517.0, 727.0),
#      (331.0, 761.0, 624.0, 786.0),
#      (319.0, 780.0, 694.0, 841.0),
#      (321.0, 776.0, 674.0, 733.0)],
#     'Teachers_box': [310, 764, 672, 758],
#     'won': True},
#    {'Circles': [(582.0, 574.0), (757.0, 504.0)],
#     'Crosses': [(585.0, 471.0), (776.0, 522.0)],
#     'Learners_guess': [(259.0, 528.0, 441.0, 582.0),
#      (547.0, 775.0, 171.0, 395.0),
#      (498.0, 732.0, 525.0, 676.0),
#      (560.0, 769.0, 500.0, 587.0)],
#     'Teachers_box': [568, 768, 485, 590],
#     'won': True},
#    {'Circles': [(212.0, 480.0), (532.0, 482.0), (341.0, 586.0)],
#     'Crosses': [(435.0, 451.0), (382.0, 608.0)],
#     'Learners_guess': [(163.0, 354.0, 432.0, 584.0),
#      (144.0, 585.0, 389.0, 626.0),
#      (199.0, 558.0, 474.0, 543.0),
#      (195.0, 559.0, 468.0, 644.0),
#      (191.0, 552.0, 466.0, 594.0)],
#     'Teachers_box': [194, 541, 465, 593],
#     'won': True},
#    {'Circles': [(647.0, 714.0)],
#     'Crosses': [(703.0, 733.0)],
#     'Learners_guess': [(570.0, 758.0, 622.0, 769.0),
#      (590.0, 684.0, 653.0, 730.0)],
#     'Teachers_box': [590, 697, 677, 763],
#     'won': True},
#    {'Circles': [(668.0, 469.0), (490.0, 698.0)],
#     'Crosses': [(315.0, 467.0), (499.0, 91.0), (484.0, 728.0)],
#     'Learners_guess': [(640.0, 707.0, 445.0, 522.0),
#      (387.0, 794.0, 429.0, 577.0),
#      (338.0, 737.0, 158.0, 520.0),
#      (327.0, 687.0, 115.0, 672.0),
#      (323.0, 691.0, 109.0, 714.0)],
#     'Teachers_box': [323, 675, 99, 716],
#     'won': True},
#    {'Circles': [(346.0, 572.0), (403.0, 678.0)],
#     'Crosses': [(422.0, 608.0), (316.0, 631.0)],
#     'Learners_guess': [(288.0, 418.0, 513.0, 634.0),
#      (300.0, 464.0, 499.0, 765.0),
#      (290.0, 414.0, 530.0, 713.0),
#      (327.0, 411.0, 551.0, 699.0)],
#     'Teachers_box': [329, 415, 557, 685],
#     'won': True},
#    {'Circles': [(596.0, 379.0), (435.0, 716.0)],
#     'Crosses': [(442.0, 347.0)],
#     'Learners_guess': [(565.0, 640.0, 288.0, 420.0),
#      (364.0, 620.0, 279.0, 736.0),
#      (425.0, 635.0, 370.0, 729.0)],
#     'Teachers_box': [417, 611, 359, 733],
#     'won': True},
#    {'Circles': [(656.0, 468.0), (681.0, 767.0), (723.0, 618.0)],
#     'Crosses': [(697.0, 781.0), (747.0, 634.0), (633.0, 565.0)],
#     'Learners_guess': [(598.0, 735.0, 388.0, 570.0),
#      (575.0, 796.0, 452.0, 763.0),
#      (582.0, 721.0, 463.0, 761.0),
#      (623.0, 706.0, 424.0, 541.0),
#      (650.0, 691.0, 456.0, 780.0),
#      (650.0, 735.0, 456.0, 774.0)],
#     'Teachers_box': [642, 728, 451, 771],
#     'won': True},
#    {'Circles': [(475.0, 323.0)],
#     'Crosses': [(482.0, 376.0)],
#     'Learners_guess': [(459.0, 594.0, 293.0, 459.0),
#      (455.0, 513.0, 284.0, 355.0)],
#     'Teachers_box': [438, 524, 280, 366],
#     'won': True},
#    {'Circles': [(334.0, 435.0), (378.0, 260.0)],
#     'Crosses': [(412.0, 245.0), (320.0, 345.0)],
#     'Learners_guess': [(343.0, 534.0, 286.0, 437.0),
#      (265.0, 464.0, 287.0, 479.0),
#      (269.0, 426.0, 252.0, 445.0),
#      (329.0, 454.0, 253.0, 440.0)],
#     'Teachers_box': [328, 414, 251, 446],
#     'won': True},
#    {'Circles': [(683.0, 233.0), (747.0, 310.0)],
#     'Crosses': [(768.0, 271.0), (661.0, 278.0)],
#     'Learners_guess': [(567.0, 721.0, 219.0, 298.0),
#      (561.0, 804.0, 215.0, 379.0),
#      (605.0, 758.0, 212.0, 364.0),
#      (669.0, 759.0, 213.0, 333.0)],
#     'Teachers_box': [672, 758, 223, 320],
#     'won': True},
#    {'Circles': [(360.0, 686.0)],
#     'Crosses': [],
#     'Learners_guess': [(328.0, 434.0, 669.0, 741.0)],
#     'Teachers_box': [347, 433, 668, 754],
#     'won': True},
#    {'Circles': [(451.0, 507.0), (458.0, 719.0), (385.0, 609.0)],
#     'Crosses': [],
#     'Learners_guess': [(424.0, 509.0, 486.0, 534.0),
#      (420.0, 528.0, 488.0, 732.0),
#      (364.0, 487.0, 497.0, 735.0)],
#     'Teachers_box': [379, 544, 492, 733],
#     'won': True},
#    {'Circles': [(482.0, 180.0), (210.0, 188.0)],
#     'Crosses': [],
#     'Learners_guess': [(444.0, 547.0, 154.0, 238.0),
#      (192.0, 502.0, 160.0, 258.0)],
#     'Teachers_box': [199, 486, 146, 232],
#     'won': True},
#    {'Circles': [(623.0, 691.0),
#      (652.0, 763.0),
#      (749.0, 728.0),
#      (526.0, 712.0)],
#     'Crosses': [],
#     'Learners_guess': [(547.0, 634.0, 544.0, 700.0),
#      (618.0, 666.0, 684.0, 776.0),
#      (615.0, 763.0, 683.0, 782.0),
#      (511.0, 770.0, 689.0, 780.0)],
#     'Teachers_box': [517, 754, 683, 769],
#     'won': True},
#    {'Circles': [(336.0, 369.0), (275.0, 499.0)],
#     'Crosses': [(360.0, 458.0)],
#     'Learners_guess': [(320.0, 565.0, 355.0, 465.0),
#      (240.0, 371.0, 356.0, 512.0),
#      (237.0, 348.0, 362.0, 506.0)],
#     'Teachers_box': [262, 348, 353, 510],
#     'won': True},
#    {'Circles': [(439.0, 491.0),
#      (520.0, 545.0),
#      (541.0, 505.0),
#      (525.0, 751.0),
#      (607.0, 681.0)],
#     'Crosses': [],
#     'Learners_guess': [(406.0, 528.0, 452.0, 555.0),
#      (431.0, 532.0, 480.0, 572.0),
#      (431.0, 564.0, 480.0, 560.0),
#      (432.0, 570.0, 484.0, 769.0),
#      (427.0, 622.0, 480.0, 769.0)],
#     'Teachers_box': [418, 614, 475, 756],
#     'won': True},
#    {'Circles': [(651.0, 606.0), (694.0, 672.0), (684.0, 760.0)],
#     'Crosses': [],
#     'Learners_guess': [(618.0, 705.0, 549.0, 683.0),
#      (649.0, 713.0, 589.0, 699.0),
#      (648.0, 705.0, 597.0, 784.0)],
#     'Teachers_box': [634, 720, 594, 768],
#     'won': True},
#    {'Circles': [(651.0, 375.0), (664.0, 612.0)],
#     'Crosses': [],
#     'Learners_guess': [(549.0, 664.0, 366.0, 459.0),
#      (632.0, 744.0, 365.0, 627.0)],
#     'Teachers_box': [619, 705, 362, 618],
#     'won': True},
#    {'Circles': [(286.0, 330.0),
#      (289.0, 239.0),
#      (345.0, 293.0),
#      (238.0, 283.0)],
#     'Crosses': [],
#     'Learners_guess': [(268.0, 464.0, 314.0, 414.0),
#      (266.0, 326.0, 210.0, 359.0),
#      (279.0, 359.0, 227.0, 355.0),
#      (226.0, 355.0, 232.0, 355.0)],
#     'Teachers_box': [235, 350, 229, 342],
#     'won': True}]},
#  {'Conscent': True,
#   'Learners_Id': 218,
#   'Learners_age': 11,
#   'Teachers_Id': 217,
#   'Teachers_age': 6,
#   'Total_time': 16.0955,
#   'Trials': [{'Circles': [(222.0, 571.0),
#      (197.0, 670.0),
#      (230.0, 474.0),
#      (123.0, 647.0)],
#     'Crosses': [(363.0, 559.0), (63.0, 563.0), (218.0, 391.0), (199.0, 799.0)],
#     'Learners_guess': [(146.0, 283.0, 526.0, 599.0),
#      (147.0, 264.0, 562.0, 697.0),
#      (154.0, 310.0, 544.0, 687.0),
#      (142.0, 247.0, 555.0, 695.0),
#      (152.0, 323.0, 537.0, 680.0),
#      (139.0, 248.0, 526.0, 707.0),
#      (174.0, 276.0, 449.0, 685.0),
#      (109.0, 277.0, 451.0, 684.0)],
#     'Teachers_box': [95, 311, 443, 771],
#     'won': False},
#    {'Circles': [(484.0, 512.0),
#      (343.0, 522.0),
#      (589.0, 511.0),
#      (675.0, 502.0)],
#     'Crosses': [(447.0, 411.0)],
#     'Learners_guess': [(557.0, 712.0, 377.0, 565.0),
#      (456.0, 507.0, 413.0, 564.0),
#      (329.0, 556.0, 481.0, 562.0),
#      (327.0, 628.0, 473.0, 583.0),
#      (321.0, 741.0, 474.0, 580.0)],
#     'Teachers_box': [294, 729, 467, 553],
#     'won': True},
#    {'Circles': [(722.0, 134.0), (711.0, 248.0)],
#     'Crosses': [],
#     'Learners_guess': [(663.0, 840.0, 57.0, 272.0),
#      (672.0, 754.0, 93.0, 292.0)],
#     'Teachers_box': [661, 777, 91, 293],
#     'won': True},
#    {'Circles': [(546.0, 563.0),
#      (543.0, 669.0),
#      (534.0, 712.0),
#      (550.0, 532.0)],
#     'Crosses': [],
#     'Learners_guess': [(435.0, 760.0, 490.0, 645.0),
#      (439.0, 773.0, 507.0, 734.0),
#      (441.0, 628.0, 517.0, 732.0),
#      (525.0, 574.0, 525.0, 729.0)],
#     'Teachers_box': [493, 579, 505, 730],
#     'won': True},
#    {'Circles': [(535.0, 535.0),
#      (583.0, 532.0),
#      (503.0, 529.0),
#      (564.0, 541.0),
#      (546.0, 511.0)],
#     'Crosses': [(459.0, 519.0)],
#     'Learners_guess': [(248.0, 328.0, 404.0, 533.0),
#      (513.0, 562.0, 486.0, 591.0),
#      (517.0, 715.0, 469.0, 576.0),
#      (488.0, 607.0, 461.0, 623.0),
#      (488.0, 654.0, 487.0, 578.0),
#      (488.0, 602.0, 498.0, 568.0)],
#     'Teachers_box': [493, 602, 482, 568],
#     'won': True},
#    {'Circles': [(518.0, 203.0), (568.0, 186.0)],
#     'Crosses': [],
#     'Learners_guess': [(469.0, 658.0, 198.0, 315.0),
#      (475.0, 585.0, 161.0, 247.0)],
#     'Teachers_box': [479, 617, 155, 241],
#     'won': True},
#    {'Circles': [(350.0, 523.0),
#      (537.0, 532.0),
#      (407.0, 616.0),
#      (609.0, 608.0),
#      (492.0, 476.0),
#      (301.0, 528.0),
#      (727.0, 545.0)],
#     'Crosses': [],
#     'Learners_guess': [(261.0, 438.0, 457.0, 568.0),
#      (321.0, 589.0, 486.0, 569.0),
#      (314.0, 573.0, 497.0, 625.0),
#      (323.0, 655.0, 508.0, 674.0),
#      (322.0, 655.0, 453.0, 648.0),
#      (273.0, 662.0, 448.0, 683.0),
#      (276.0, 787.0, 452.0, 652.0)],
#     'Teachers_box': [271, 765, 435, 671],
#     'won': True},
#    {'Circles': [(179.0, 333.0), (262.0, 337.0)],
#     'Crosses': [],
#     'Learners_guess': [(103.0, 465.0, 279.0, 416.0),
#      (114.0, 323.0, 283.0, 383.0)],
#     'Teachers_box': [126, 351, 300, 386],
#     'won': True},
#    {'Circles': [(447.0, 317.0),
#      (639.0, 322.0),
#      (424.0, 513.0),
#      (685.0, 521.0)],
#     'Crosses': [],
#     'Learners_guess': [(327.0, 526.0, 283.0, 350.0),
#      (425.0, 712.0, 274.0, 373.0),
#      (397.0, 659.0, 274.0, 541.0),
#      (400.0, 721.0, 279.0, 554.0)],
#     'Teachers_box': [383, 707, 278, 561],
#     'won': True},
#    {'Circles': [(584.0, 281.0), (605.0, 285.0), (554.0, 275.0)],
#     'Crosses': [],
#     'Learners_guess': [(530.0, 618.0, 217.0, 374.0),
#      (574.0, 720.0, 214.0, 380.0),
#      (534.0, 659.0, 214.0, 341.0)],
#     'Teachers_box': [539, 625, 239, 325],
#     'won': True},
#    {'Circles': [(667.0, 515.0), (670.0, 662.0)],
#     'Crosses': [],
#     'Learners_guess': [(620.0, 752.0, 445.0, 569.0),
#      (627.0, 770.0, 434.0, 708.0)],
#     'Teachers_box': [598, 753, 467, 747],
#     'won': True},
#    {'Circles': [(649.0, 179.0)],
#     'Crosses': [],
#     'Learners_guess': [(601.0, 726.0, 135.0, 260.0)],
#     'Teachers_box': [611, 697, 144, 230],
#     'won': True},
#    {'Circles': [(720.0, 646.0), (718.0, 699.0), (703.0, 668.0)],
#     'Crosses': [],
#     'Learners_guess': [(655.0, 828.0, 590.0, 690.0),
#      (655.0, 830.0, 595.0, 706.0),
#      (660.0, 769.0, 623.0, 719.0)],
#     'Teachers_box': [678, 764, 620, 706],
#     'won': True},
#    {'Circles': [(227.0, 315.0),
#      (219.0, 543.0),
#      (218.0, 608.0),
#      (219.0, 252.0)],
#     'Crosses': [],
#     'Learners_guess': [(177.0, 365.0, 290.0, 407.0),
#      (181.0, 324.0, 310.0, 569.0),
#      (182.0, 289.0, 308.0, 641.0),
#      (192.0, 310.0, 236.0, 630.0)],
#     'Teachers_box': [177, 263, 247, 614],
#     'won': True},
#    {'Circles': [(669.0, 104.0), (681.0, 171.0)],
#     'Crosses': [],
#     'Learners_guess': [(605.0, 766.0, 77.0, 160.0),
#      (607.0, 719.0, 83.0, 190.0)],
#     'Teachers_box': [629, 715, 90, 176],
#     'won': True}]}]

# %%
Data[0]['Trials'][0]['Learners_guess'][-1]
# Out:
# (471.0, 589.0, 166.0, 433.0)

# %%
def draw_trial(trial):
    box=trial['Teachers_box'];
    box_lerner=trial['Learners_guess'][-1];
    fig=plt.figure;
    plt.plot([box[0],box[0],box[1],box[1],box[0]],[box[3],box[2],box[2],box[3],box[3]],'b')
    plt.plot([box_lerner[0],box_lerner[0],box_lerner[1],box_lerner[1],box_lerner[0]],[box_lerner[3],box_lerner[2],box_lerner[2],box_lerner[3],box_lerner[3]],'r')
    for circle in trial['Circles']:
        plt.plot(circle[0],circle[1],'og')    
    for cross in trial['Crosses']:
        plt.plot(cross[0],cross[1],'xk')                
    plt.show()
    plt.ylim([0,864]);
    plt.xlim([0,864]);

# %%
for d in Data:
    print('Learners Age:',d['Learners_age'],'Teachers Age',d['Teachers_age'])
    for t in d['Trials']:
        print('won:',t['won'])
        draw_trial(t)
# Out:
# Learners Age: 35 Teachers Age 40
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 10 Teachers Age 10
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 12 Teachers Age 10
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 18 Teachers Age 16
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 10 Teachers Age 10
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 7 Teachers Age 8
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 56 Teachers Age 42
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 7 Teachers Age 7
# won: False
# won: True
# won: False
# won: False
# won: False
# Learners Age: 10 Teachers Age 10
# won: False
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 8 Teachers Age 8
# won: False
# won: False
# won: False
# won: False
# won: True
# Learners Age: 50 Teachers Age 38
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 9 Teachers Age 10
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 9 Teachers Age 9
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 52 Teachers Age 56
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 20 Teachers Age 28
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# Learners Age: 11 Teachers Age 6
# won: False
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True
# won: True

# %%
n_trials=[];
n_examples=[];
sd_examples=[];
n_examples_win=[];
sd_examples_win=[];
p_win=[];
time=[];
edades=[];
workable_trial=0;
non_workable_trial=0;
workable_couple=0;
for P in Data:
    edades.append(str(P['Teachers_age'])+'-'+str(P['Learners_age']))
    n_trials.append(len(P['Trials']));    
    time.append(P['Total_time']);    
    nex=[];
    nex_w=[];
    n_won=0;
    for trial in P['Trials']:
        nex.append(len(trial['Circles'])+len(trial['Crosses']));
        if trial['won']:
            nex_w.append(len(trial['Circles'])+len(trial['Crosses']));            
    n_examples.append(np.mean(nex));
    sd_examples.append(np.std(nex));
    n_examples_win.append(np.mean(nex_w));
    sd_examples_win.append(np.std(nex_w));
    p_win.append(len(nex_w)/len(nex));
    flag=True;
    if not(P['Conscent']):
        print(P['Teachers_Id'])
    for trial in P['Trials']:
        if not trial['Crosses'] or not trial['Circles']:            
            workable_trial+=1;
            if flag:
                workable_couple+=1;
                flag=False;

# %%
a=[1,2,3]
np.std(a)

# %%
print('Edades','||||','Trials','||||','% win','||||','av. examples','||||','av. examples|w','||||','time')
[print (*[edades[i],'||||',n_trials[i],'||||',round(p_win[i]*10)/10,'||||',round(n_examples[i]*10)/10,'+/-',round(sd_examples[i]*10)/10,'||||',round(n_examples_win[i]*10)/10,'+/-',round(sd_examples_win[i]*10)/10,'||||',round(time[i]*10)/10]) for i in range(0,len(time))];

# %%
def individual_histogram(pair,center): # as in the paper. # center: make the box be in the center of the crosses histogram
    n_bins=3;
    canvas_size=865;
    inner_bins=np.zeros([n_bins,n_bins]); 
    if center:
        outer_bins=np.zeros([2*n_bins+1,2*n_bins+1]);             
    else:
        outer_bins=np.zeros([n_bins+1,n_bins+1]);             
    n_trial=-1;
    for trial in pair['Trials']:
            n_trial=n_trial+1;
            box=trial['Teachers_box'];
            width=box[1]-box[0];
            height=box[3]-box[2];                
            for circle in trial['Circles']:
                x=circle[0]-box[0];
                y=circle[1]-box[2];
                x_bin=np.int(np.floor(x/(width/n_bins)));
                y_bin=np.int(np.floor(y/(height/n_bins)));
                if(x_bin==3):
                    x_bin=2;
                if(y_bin==3):
                    y_bin=2;                
                inner_bins[x_bin,y_bin ]=inner_bins[x_bin,y_bin]+1;                
            for cross in trial['Crosses']:
                if (cross[0]-box[0])<0: #left side
                    x=box[0]-cross[0];
                    x_bin=np.int(np.floor(x/(box[0]/n_bins)))+1; # bins 1,2 or 3
                    if center:
                        x_bin=-x_bin+n_bins; # make the box be in the center
                elif cross[0]>box[1]: #right side
                    x=cross[0]-box[1];
                    x_bin=np.int(np.floor(x/((canvas_size-box[1])/n_bins)))+1;
                    if center:
                        x_bin=x_bin+n_bins;
                else: # above or below the box
                    x_bin=0;
                    if center:
                        x_bin=x_bin+n_bins;
                if (cross[1]-box[2])<0: # above
                    y=box[2]-cross[1];
                    y_bin=np.int(np.floor(y/(box[2]/n_bins)))+1;
                    if center:
                        y_bin=y_bin+n_bins;
                elif cross[1]>box[3]: # below
                    y=cross[1]-box[3];
                    y_bin=np.int(np.floor(y/((canvas_size-box[3])/n_bins)))+1;
                    if center:
                        y_bin=-y_bin+n_bins;
                else:                                                                              
                    y_bin=0;                
                    if center:
                        y_bin=y_bin+n_bins;
                outer_bins[x_bin,y_bin]=outer_bins[x_bin,y_bin]+1;            
    return inner_bins, outer_bins;


def plot_inner_histo(histo_inside):
    fig=plt.figure();
    plt.pcolor(np.flip(histo_inside,0),cmap='Greys')     
    plt.colorbar();    
    plt.plot([0,3,3,0,0],[0,0,3,3,0],'b')
    plt.xlim([-0.5,3.5])
    plt.ylim([-0.5,3.5])
    plt.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False,labelleft=False)    
    plt.show()
    
    
    
def plot_outer_histo(histo_outside,center):
    fig=plt.figure();
    plt.title('')        
    if center:
        plt.pcolor(np.flip(histo_outside,0),cmap='Greys')
        plt.plot([3,4,4,3,3],[3,3,4,4,3],'b')
        plt.xlim([0,7])
        plt.ylim([0,7])    
    else:
        plt.pcolor(histo_outside,cmap='Greys')
        plt.plot([0,1,1,0,0],[0,0,1,1,0],'b')
        plt.xlim([-0.03,4])
        plt.ylim([-0.01,4])    
    plt.colorbar();    
    plt.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False,labelleft=False)
    plt.show()

# %%
i=0;
for pair in Data:    
    [inner,outer]=individual_histogram(pair,True);
    print('Edad-T:'+str(pair['Teachers_age'])+' Edad-L:'+str(pair['Learners_age']))
    plot_inner_histo(inner)
    plot_outer_histo(outer,True)

# %%
print(inner)
print(np.flip(inner,0))
